# %%
# !python DANmodels.py --model 2a
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     /Users/anaykulkarni/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
#
#
# Evaluating effect of vocabulary length on Accuracy:
# Before running BPE algorithm-------
# 	Word-level vocab size:  14830
# 	Subword-level vocab size:  65
# After running BPE algorithm--------
# 	Word-level vocab size:  14830
# 	Subword-level vocab size:  472
#
# Compression Ratio:  31.41949152542373
#
# Training (from scratch) and Evaluating a 3 Layer Neural Network using BPE (training) vocabulary size:  472
#
# Training completed in : 46.58051776885986 seconds
# Evaluation completed in : 1.7520179748535156 seconds
#
# Peak Train Accuracy achieved:  0.7716763005780347
# Peak Test Accuracy achieved:  0.7385321100917431
# Before running BPE algorithm-------
# 	Word-level vocab size:  14830
# 	Subword-level vocab size:  65
# After running BPE algorithm--------
# 	Word-level vocab size:  14830
# 	Subword-level vocab size:  924
#
# ...
