# %%
#!python DANmodels.py

# %%
# Torch and related PyTorch libraries
import torch
from torch import nn  # Neural networks
import torch.nn.functional as F  # Functional API
from torch.utils.data import Dataset, DataLoader  # Data utilities

# NLP Preprocessing Libraries (nltk)
import nltk
from nltk.tokenize import word_tokenize, sent_tokenize  # Tokenizers
from nltk.corpus import stopwords  # Stop words
from nltk.stem import PorterStemmer  # Stemmer


# Utility and Helper Libraries
from typing import List  # Type hinting
import collections
from collections import Counter, defaultdict  # Counting elements
import re  # Regular expressions
import numpy as np  # Numerical computations
import time  # Time tracking
import argparse  # Argument parsing
import matplotlib.pyplot as plt  # Plotting
from torch.nn.utils.rnn import pad_sequence
import string

# %%
class SentimentExample:
    """
    Data wrapper for a single example for sentiment analysis.

    Attributes:
        words (List[string]): list of words
        label (int): 0 or 1 (0 = negative, 1 = positive)
    """

    def __init__(self, words, label):
        self.words = words
        self.label = label

    def __repr__(self):
        return repr(self.words) + "; label=" + repr(self.label)

    def __str__(self):
        return self.__repr__()

# %%
def read_sentiment_examples(infile: str) -> List[SentimentExample]:
    """
    Reads sentiment examples in the format [0 or 1]<TAB>[raw sentence]; tokenizes and cleans the sentences and forms
    SentimentExamples.

    Note that we lowercase the data for you. This is because the GloVe embeddings don't
    distinguish case and so can only be used with lowercasing.

    :param infile: file to read from
    :return: a list of SentimentExamples parsed from the file
    """
    f = open(infile)
    exs = []
    for line in f:
        if len(line.strip()) > 0:
            fields = line.split("\t")
            if len(fields) != 2:
                fields = line.split()
                label = 0 if "0" in fields[0] else 1
                sent = " ".join(fields[1:]).lower()
            else:
                # Slightly more robust to reading bad output than int(fields[0])
                label = 0 if "0" in fields[0] else 1
                sent = fields[1].lower()
            tokenized_cleaned_sent = list(filter(lambda x: x != '', sent.rstrip().split(" ")))
            exs.append(SentimentExample(tokenized_cleaned_sent, label))
    f.close()
    return exs

# %%
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     /Users/anaykulkarni/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
# Function to get symbol pairs and their frequencies
def get_stats(vocab):
    pairs = collections.defaultdict(int)
    for word, freq in vocab.items():
        symbols = word.split()
        for i in range(len(symbols) - 1):
            pairs[symbols[i], symbols[i + 1]] += freq
    return pairs

# Function to merge the most frequent pair
def merge_vocab(pair, v_in):
    v_out = {}
    bigram = re.escape(' '.join(pair))
    p = re.compile(r'(?<!\S)' + bigram + r'(?!\S)')
    for word in v_in:
        w_out = p.sub(''.join(pair), word)
        v_out[w_out] = v_in[word]
    return v_out

# Number of merge operations
# num_merges = 10

def initialize_vocab(infile):
    vocab = defaultdict(int)
    exs = read_sentiment_examples(infile)
    for ex in exs:
        for word in ex.words:
            subword_format = ' '.join(list(word)) + ' </w>'
            vocab[subword_format] += 1
    return vocab

def perform_bpe_merges(num_merges, vocab): 
    for i in range(num_merges):
        pairs = get_stats(vocab)
        best = max(pairs, key=pairs.get)
        vocab = merge_vocab(best, vocab)
        #print(f'Merge {i + 1}: {best}')
    return vocab

def get_subword_vocab(bpe_vocab):
    subword_vocab = defaultdict(int)
    #Add the UNK token to the subword vocabulary
    subword_vocab["UNK"] = 0
    for word, count in bpe_vocab.items():
        # Remove the '</w>' marker
        subwords = word.replace('</w>', '').split()
        # Count each subword
        for subword in subwords:
            subword_vocab[subword] += count
    return subword_vocab

def build_bpe_subword_vocab(infile, merges):
    word_vocab = initialize_vocab(infile)
    pre_bpe_subword_vocab = get_subword_vocab(word_vocab)

    print('Before running BPE algorithm-------')
    print('\tWord-level vocab size: ', len(word_vocab))
    print('\tSubword-level vocab size: ', len(pre_bpe_subword_vocab))

    word_vocab = perform_bpe_merges(merges, word_vocab)
    post_bpe_subword_vocab = get_subword_vocab(word_vocab)

    print('After running BPE algorithm--------')
    print('\tWord-level vocab size: ', len(word_vocab))
    print('\tSubword-level vocab size: ', len(post_bpe_subword_vocab))
    print('\nCompression Ratio: ', len(word_vocab)/len(post_bpe_subword_vocab))

    return post_bpe_subword_vocab

def tokenize_bpe(text, vocab):
    # Tokenize text using BPE vocabulary
    words = text.split()
    tokenized_text = []

    # For each word in the list of words
    for word in words:
        subword = []
        i = 0
        # i index starts from beginning of word 
        while i < len(word):
            # Look for the longest subword in the vocabulary that matches the word prefix
            found = False
            #  and j index from the back.
            for j in range(len(word), i, -1):
                sub_token = word[i:j]
                if sub_token in vocab:
                    subword.append(sub_token)
                    i = j  # Move index past the subword
                    found = True
                    break
            if not found:
                subword.append(word[i])  # Add the character if no subword is found
                i += 1
                
        tokenized_text.append(' '.join(subword)) # Join as a sentence of subwords
    
    return ' '.join(tokenized_text) # return tokenized text as a sentence(s) of subwords

# %%
myvocab = build_bpe_subword_vocab('data/train.txt', 40000)
# Out:
# Before running BPE algorithm-------
# 	Word-level vocab size:  14830
# 	Subword-level vocab size:  65
# After running BPE algorithm--------
# 	Word-level vocab size:  14830
# 	Subword-level vocab size:  10401
#
# Compression Ratio:  1.4258244399576965

# %%
counter=0
for word, freq in myvocab.items():
    print(counter, word, freq)
    counter += 1
# Out:
# 0 the 5998
# 1 rock 23
# 2 is 2266
# 3 dest 16
# 4 ined 33
# 5 to 2506
# 6 be 665
# 7 21 6
# 8 st 218
# 9 century 13
# 10 's 2025
# 11 new 149
# 12 `` 210
# 13 con 93
# 14 an 1163
# 15 '' 209
# 16 and 3889
# 17 that 1613
# 18 he 232
# 19 going 62
# 20 make 157
# 21 a 4766
# 22 spl 20
# 23 ash 74
# 24 even 227
# 25 great 103
# 26 er 408
# 27 than 400
# 28 ar 269
# 29 n 282
# 30 old 76
# 31 sch 66
# 32 war 77
# 33 z 148
# 34 ene 5
# 35 g 281
# 36 ger 47
# 37 , 5885
# 38 je 17
# 39 an- 17
# 40 cl 107
# 41 au 70
# 42 d 444
# 43 v 195
# 44 dam 17
# 45 me 160
# 46 or 535
# 47 steven 16
# 48 se 138
# 49 al 329
# 50 . 6610
# 51 gor 16
# 52 ge 103
# 53 ously 55
# 54 el 247
# 55 abor 12
# 56 ate 162
# 57 continu 7
# 58 ation 146
# 59 of 3658
# 60 l 270
# 61 ord 14
# 62 r 257
# 63 ings 64
# 64 tr 82
# 65 il 111
# 66 og 20
# 67 y 381
# 68 so 350
# 69 huge 15
# 70 col 32
# 71 um 126
# 72 words 20
# 73 can 225
# 74 not 460
# 75 adequ 10
# 76 ately 36
# 77 descri 12
# 78 co- 14
# 79 writer\/director 11
# 80 peter 13
# 81 jackson 17
# 82 exp 15
# 83 ed 490
# 84 vision 23
# 85 j 140
# 86 r. 6
# 87 tol 10
# 88 ki 26
# 89 en 246
# 90 middle- 13
# 91 earth 12
# 92 sing 35
# 93 er\/ 3
# 94 com 69
# 95 pos 34
# 96 br 90
# 97 ad 153
# 98 ams 16
# 99 contri 14
# 100 bu 78
# 101 t 579
# 102 es 461
# 103 sle 27
# 104 w 216
# 105 songs 10
# 106 -- 424
# 107 few 73
# 108 potential 10
# 109 hits 10
# 110 more 424
# 111 simply 43
# 112 int 50
# 113 ru 40
# 114 sive 45
# 115 story 298
# 116 but 853
# 117 whole 42
# 118 p 373
# 119 ack 52
# 120 age 90
# 121 certainly 35
# 122 captures 22
# 123 intended 12
# 124 spirit 38
# 125 piece 54
# 126 yet 67
# 127 act 61
# 128 still 94
# 129 charming 35
# 130 here 87
# 131 whether 27
# 132 you 675
# 133 're 97
# 134 ligh 28
# 135 ten 37
# 136 by 484
# 137 any 173
# 138 der 76
# 139 ri 104
# 140 da 44
# 141 ec 56
# 142 tures 10
# 143 on 771
# 144 other 111
# 145 self 13
# 146 undeniably 10
# 147 fascinating 55
# 148 playful 9
# 149 fell 10
# 150 ow 98
# 151 just 244
# 152 lab 24
# 153 our 108
# 154 involved 13
# 155 in 1977
# 156 creating 10
# 157 lay 11
# 158 ered 39
# 159 rich 42
# 160 ness 103
# 161 imagery 8
# 162 this 830
# 163 chi 19
# 164 os 108
# 165 cur 37
# 166 o 292
# 167 ma 110
# 168 dness 19
# 169 light 47
# 170 astonishing 7
# 171 part 67
# 172 charm 39
# 173 sat 4
# 174 ou 62
# 175 it 2144
# 176 av 34
# 177 ids 11
# 178 obvious 30
# 179 with 964
# 180 humour 9
# 181 screenplay 46
# 182 ingen 11
# 183 iously 19
# 184 constructed 11
# 185 mem 5
# 186 extreme 13
# 187 ops 25
# 188 exc 31
# 189 e 471
# 190 eds 15
# 191 expectations 7
# 192 good 215
# 193 fun 107
# 194 action 130
# 195 acting 77
# 196 dialogue 63
# 197 pace 16
# 198 cinematography 13
# 199 dra 10
# 200 mas 17
# 201 like 428
# 202 human 79
# 203 flick 45
# 204 h 230
# 205 ost 18
# 206 some 207
# 207 truly 30
# 208 excellent 22
# 209 sequences 28
# 210 austr 11
# 211 alian 3
# 212 \/ 48
# 213 director 159
# 214 john 30
# 215 pol 18
# 216 son 57
# 217 aw 56
# 218 d- 44
# 219 winning 19
# 220 english 7
# 221 cinemat 2
# 222 ograph 16
# 223 nu 20
# 224 tt 33
# 225 gen 38
# 226 s 443
# 227 terrific 28
# 228 effort 38
# 229 at 597
# 230 disgu 11
# 231 ing 440
# 232 energy 36
# 233 innov 8
# 234 walk 11
# 235 out 320
# 236 girl 34
# 237 mixed 10
# 238 emotions 17
# 239 disap 5
# 240 prov 12
# 241 ju 26
# 242 ine 96
# 243 comb 13
# 244 understanding 9
# 245 for 871
# 246 her 146
# 247 ac 94
# 248 tions 73
# 249 absorbing 13
# 250 character 100
# 251 study 42
# 252 é 27
# 253 tur 28
# 254 if 304
# 255 love 145
# 256 reading 12
# 257 poetry 15
# 258 then 56
# 259 all 443
# 260 means 13
# 261 check 10
# 262 'll 68
# 263 probably 40
# 264 frailty 8
# 265 has 446
# 266 been 152
# 267 written 37
# 268 well 120
# 269 simple 25
# 270 god 16
# 271 m 321
# 272 ! 62
# 273 gr 91
# 274 ier 5
# 275 inging 16
# 276 un 398
# 277 forced 20
# 278 rap 17
# 279 id 122
# 280 - 474
# 281 fire 28
# 282 delivery 9
# 283 back 102
# 284 ide 24
# 285 ni 39
# 286 et 111
# 287 e- 95
# 288 refer 5
# 289 enc 11
# 290 actors 69
# 291 are 459
# 292 fantastic 8
# 293 they 165
# 294 what 270
# 295 makes 150
# 296 worth 64
# 297 trip 17
# 298 theatre 10
# 299 -lrb- 286
# 300 ta 61
# 301 ym 17
# 302 -rrb- 287
# 303 u 177
# 304 ti 136
# 305 li 113
# 306 idea 43
# 307 making 62
# 308 ka 11
# 309 art 70
# 310 living 14
# 311 brea 16
# 312 thing 85
# 313 movie 817
# 314 often 88
# 315 cat 28
# 316 ap 69
# 317 ul 102
# 318 ting 87
# 319 artist 18
# 320 into 249
# 321 own 132
# 322 work 179
# 323 n't 535
# 324 done 49
# 325 before 66
# 326 never 159
# 327 vividly 10
# 328 much 209
# 329 passion 23
# 330 take 74
# 331 care 45
# 332 my 105
# 333 honestly 9
# 334 nice 19
# 335 little 174
# 336 film 965
# 337 takes 59
# 338 us 229
# 339 examination 19
# 340 young 55
# 341 adult 11
# 342 life 152
# 343 urban 23
# 344 south 9
# 345 k 376
# 346 ore 34
# 347 through 131
# 348 hearts 8
# 349 min 49
# 350 ds 82
# 351 five 14
# 352 princ 8
# 353 ip 16
# 354 als 50
# 355 emp 22
# 356 ire 9
# 357 lacks 33
# 358 depth 20
# 359 up 295
# 360 its 809
# 361 heart 80
# 362 silly 35
# 363 photo 14
# 364 graphed 9
# 365 rather 66
# 366 time 210
# 367 ton 41
# 368 gu 80
# 369 in- 26
# 370 che 56
# 371 ek 25
# 372 pre 88
# 373 poster 8
# 374 ousness 21
# 375 always 37
# 376 most 258
# 377 wilde 7
# 378 dr 49
# 379 ol 101
# 380 whim 11
# 381 sy 57
# 382 hel 25
# 383 ps 39
# 384 being 90
# 385 earnest 23
# 386 overcome 14
# 387 wea 7
# 388 kn 14
# 389 esses 13
# 390 parker 11
# 391 creative 18
# 392 inter 54
# 393 fer 31
# 394 ence 67
# 395 ... 525
# 396 lies 21
# 397 utter 8
# 398 cut 32
# 399 eness 23
# 400 stu 25
# 401 mar 63
# 402 gol 6
# 403 their 181
# 404 comput 5
# 405 er- 35
# 406 animated 21
# 407 f 214
# 408 aces 16
# 409 very 154
# 410 expres 25
# 411 sp 116
# 412 iced 7
# 413 humor 103
# 414 ' 347
# 415 i 665
# 416 spe 22
# 417 ak 41
# 418 flu 25
# 419 ent 196
# 420 flat 39
# 421 vis 29
# 422 den 56
# 423 lop 7
# 424 after 92
# 425 b 291
# 426 bly 10
# 427 ex 120
# 428 change 22
# 429 ali 37
# 430 dec 42
# 431 hand 51
# 432 witty 19
# 433 sil 17
# 434 ver 71
# 435 par 69
# 436 ot 62
# 437 replaced 7
# 438 mor 62
# 439 ph 79
# 440 cute 12
# 441 cre 31
# 442 ature 9
# 443 who 256
# 444 im 144
# 445 ics 41
# 446 everyone 33
# 447 everything 39
# 448 around 42
# 449 there 260
# 450 tu 24
# 451 á 2
# 452 ambi 14
# 453 comes 76
# 454 from 388
# 455 bra 38
# 456 ve 76
# 457 hi 33
# 458 ited 26
# 459 performances 111
# 460 lead 31
# 461 focus 7
# 462 works 69
# 463 as 1219
# 464 unusual 8
# 465 bi 54
# 466 opic 10
# 467 document 21
# 468 male 10
# 469 sw 34
# 470 ers 162
# 471 play 53
# 472 boy 28
# 473 era 18
# 474 sour 11
# 475 core 16
# 476 ; 75
# 477 exploration 11
# 478 iness 39
# 479 under 112
# 480 ay 36
# 481 relent 7
# 482 less 162
# 483 ga 22
# 484 ety 8
# 485 19 31
# 486 20 16
# 487 ending 45
# 488 was 135
# 489 ? 100
# 490 feeling 37
# 491 deal 14
# 492 master 32
# 493 3 36
# 494 should 109
# 495 come 75
# 496 warning 7
# 497 serious 33
# 498 buff 8
# 499 only 171
# 500 made 120
# 501 uninten 9
# 502 tionally 17
# 503 fam 13
# 504 ous 126
# 505 qu 69
# 506 eas 7
# 507 y- 76
# 508 stom 14
# 509 ach 54
# 510 cri 38
# 511 tic 105
# 512 agg 8
# 513 theater 32
# 514 bl 103
# 515 acked 7
# 516 ob 61
# 517 believe 32
# 518 one 477
# 519 beautiful 38
# 520 evocative 7
# 521 've 78
# 522 seen 67
# 523 gar 30
# 524 c 240
# 525 í 1
# 526 ber 55
# 527 tal 38
# 528 anc 24
# 529 ó 2
# 530 men 53
# 531 sely 11
# 532 appealing 21
# 533 couple 16
# 534 though 86
# 535 predictable 41
# 536 want 46
# 537 things 66
# 538 spoof 8
# 539 comedy 219
# 540 carries 10
# 541 share 13
# 542 laughs 46
# 543 sometimes 49
# 544 chuck 7
# 545 le 193
# 546 ff 57
# 547 pleasure 29
# 548 occasion 6
# 549 belly 12
# 550 laugh 33
# 551 city 22
# 552 reminds 8
# 553 how 119
# 554 real 106
# 555 istically 9
# 556 anced 16
# 557 robert 21
# 558 de 202
# 559 niro 12
# 560 performance 83
# 561 when 125
# 562 luc 21
# 563 ra 122
# 564 tively 29
# 565 engag 9
# 566 sham 10
# 567 eless 48
# 568 self- 67
# 569 car 96
# 570 ic 214
# 571 ` 206
# 572 analy 8
# 573 ze 41
# 574 199 7
# 575 9 43
# 576 promis 6
# 577 thre 10
# 578 ened 14
# 579 lat 16
# 580 year 78
# 581 wan 14
# 582 sli 9
# 583 per 102
# 584 \* 7
# 585 cor 34
# 586 am 125
# 587 able 168
# 588 jer 18
# 589 king 63
# 590 re 291
# 591 shap 19
# 592 ys 32
# 593 ical 65
# 594 space 12
# 595 would 149
# 596 watch 63
# 597 kids 55
# 598 use 36
# 599 intr 14
# 600 od 69
# 601 uce 8
# 602 video 40
# 603 starts 23
# 604 typical 14
# 605 ble 68
# 606 killer 9
# 607 turns 33
# 608 signific 9
# 609 antly 44
# 610 different 25
# 611 better 108
# 612 films 108
# 613 theme 10
# 614 those 100
# 615 ride 32
# 616 themselves 23
# 617 sophisticated 15
# 618 disc 20
# 619 ning 32
# 620 taste 17
# 621 might 86
# 622 seem 68
# 623 prop 21
# 624 te 75
# 625 however 15
# 626 almost 71
# 627 guarante 7
# 628 iest 7
# 629 cinema 60
# 630 goers 4
# 631 will 214
# 632 \*\* 5
# 633 off 119
# 634 hour 47
# 635 -and- 26
# 636 a- 22
# 637 half 44
# 638 cuts 7
# 639 actually 43
# 640 face 39
# 641 your 168
# 642 fears 14
# 643 world 86
# 644 boys 14
# 645 big 95
# 646 metap 4
# 647 hor 17
# 648 wa 31
# 649 wh 51
# 650 ever 123
# 651 welcome 21
# 652 reli 19
# 653 ef 26
# 654 bas 22
# 655 ball 38
# 656 movies 131
# 657 try 24
# 658 too 265
# 659 hard 79
# 660 th 184
# 661 sweet 58
# 662 modest 9
# 663 ultimately 67
# 664 crisp 8
# 665 psychological 23
# 666 drama 146
# 667 thriller 77
# 668 have 370
# 669 perfect 35
# 670 wil 30
# 671 ight 13
# 672 zone 11
# 673 episode 16
# 674 moments 63
# 675 insightful 15
# 676 enough 144
# 677 fon 7
# 678 dly 43
# 679 remember 23
# 680 end 160
# 681 lessly 21
# 682 challenging 8
# 683 clu 10
# 684 resonant 9
# 685 gem 10
# 686 rel 25
# 687 ays 12
# 688 universal 13
# 689 points 14
# 690 without 107
# 691 fron 11
# 692 tations 7
# 693 coc 8
# 694 ke 91
# 695 provides 17
# 696 window 7
# 697 sub 59
# 698 culture 39
# 699 ell 64
# 700 -b 16
# 701 itself 66
# 702 every 118
# 703 way 189
# 704 imagin 7
# 705 smart 45
# 706 ste 42
# 707 amy 8
# 708 mix 19
# 709 road 20
# 710 coming-of-age 23
# 711 political 21
# 712 satire 26
# 713 moder 10
# 714 n- 11
# 715 day 67
# 716 ro 46
# 717 nothing 109
# 718 these 72
# 719 guys 20
# 720 sc 73
# 721 fair 20
# 722 marri 2
# 723 reason 38
# 724 live 25
# 725 hap 9
# 726 pi 52
# 727 ly 184
# 728 fact 40
# 729 best 132
# 730 recent 31
# 731 memory 16
# 732 birthday 7
# 733 actor 32
# 734 first 86
# 735 em 87
# 736 wal 33
# 737 ked 56
# 738 away 50
# 739 version 39
# 740 e.t. 7
# 741 hop 28
# 742 mo 45
# 743 ist 45
# 744 eyes 23
# 745 dev 30
# 746 french 34
# 747 safe 7
# 748 duc 13
# 749 period 19
# 750 ying 48
# 751 cell 7
# 752 oid 7
# 753 heaven 12
# 754 really 117
# 755 about 434
# 756 characters 199
# 757 resem 12
# 758 ance 85
# 759 children 40
# 760 absur 21
# 761 dis 111
# 762 ider 10
# 763 we 213
# 764 happy 15
# 765 list 15
# 766 ening 22
# 767 watching 72
# 768 them 92
# 769 slow 30
# 770 ade 23
# 771 fascin 7
# 772 ates 68
# 773 right 62
# 774 mention 10
# 775 sol 30
# 776 years 60
# 777 now 32
# 778 'm 33
# 779 sure 39
# 780 saw 16
# 781 op 94
# 782 ion 29
# 783 allen 22
# 784 funniest 10
# 785 gl 71
# 786 orious 13
# 787 spectacle 14
# 788 gri 14
# 789 early 8
# 790 days 21
# 791 comic 49
# 792 delightful 21
# 793 derivative 14
# 794 timely 10
# 795 could 127
# 796 dre 15
# 797 quietly 13
# 798 lyrical 8
# 799 tale 84
# 800 prob 6
# 801 ambigu 9
# 802 ext 26
# 803 ended 21
# 804 ir 79
# 805 af 25
# 806 gh 41
# 807 fu 36
# 808 stre 13
# 809 across 18
# 810 bor 42
# 811 ders 29
# 812 desperate 9
# 813 food 9
# 814 line 41
# 815 kos 7
# 816 sky 8
# 817 sharp 19
# 818 cu 38
# 819 tting 19
# 820 impres 18
# 821 sions 38
# 822 shows 30
# 823 signs 11
# 824 detail 10
# 825 sed 31
# 826 images 24
# 827 striking 11
# 828 tra 64
# 829 production 27
# 830 enorm 9
# 831 amount 21
# 832 affection 11
# 833 each 33
# 834 worthwhile 13
# 835 winds 8
# 836 both 103
# 837 revelatory 8
# 838 nar 18
# 839 iss 9
# 840 istic 39
# 841 achiev 9
# 842 honest 33
# 843 insight 16
# 844 relationships 19
# 845 high- 18
# 846 concept 22
# 847 cand 3
# 848 co 63
# 849 pat 21
# 850 lines 16
# 851 precious 8
# 852 cir 17
# 853 cum 9
# 854 ances 25
# 855 stars 15
# 856 eccentr 8
# 857 inspiring 13
# 858 pure 18
# 859 joy 11
# 860 spielberg 21
# 861 brings 18
# 862 another 79
# 863 masterpiece 20
# 864 finally 23
# 865 fren 4
# 866 ch 228
# 867 produced 12
# 868 read 33
# 869 lips 7
# 870 stands 14
# 871 must 29
# 872 ms. 15
# 873 ig 14
# 874 ner 64
# 875 mr. 46
# 876 ser 30
# 877 ult 11
# 878 bring 21
# 879 fresh 46
# 880 natur 11
# 881 alism 24
# 882 ag 97
# 883 sn 22
# 884 app 26
# 885 moving 55
# 886 pictures 18
# 887 today 12
# 888 solid 35
# 889 pe 69
# 890 di 128
# 891 gree 3
# 892 front 13
# 893 speci 11
# 894 fic 20
# 895 ally 55
# 896 behind 17
# 897 camera 33
# 898 no 264
# 899 sl 58
# 900 unk 12
# 901 point 59
# 902 fans 44
# 903 mov 16
# 904 edge 16
# 905 ats 23
# 906 dynam 7
# 907 touching 28
# 908 transc 7
# 909 encoura 9
# 910 go 92
# 911 see 113
# 912 unique 14
# 913 entertaining 80
# 914 twist 9
# 915 classic 26
# 916 ale 20
# 917 wo 35
# 918 sor 29
# 919 ry 60
# 920 literary 8
# 921 ective 8
# 922 disappointed 7
# 923 high 53
# 924 mes 10
# 925 fre 47
# 926 ely 75
# 927 combines 7
# 928 typ 3
# 929 ca 90
# 930 help 22
# 931 eng 24
# 932 audience 88
# 933 fan 32
# 934 series 42
# 935 twice 11
# 936 celebr 14
# 937 group 10
# 938 spark 17
# 939 non 28
# 940 form 42
# 941 ity 106
# 942 ancing 5
# 943 grand 18
# 944 called 17
# 945 his 355
# 946 ang 60
# 947 els 25
# 948 onic 20
# 949 ridiculous 9
# 950 mon 44
# 2002 vil 8
# 2003 storyline 12
# 2004 the- 13
# 2005 scrip 12
# 2006 wash 6
# 2007 sum 35
# 2008 ean 19
# 2009 visuals 10
# 2010 ock 42
# 2011 fisher 8
# 2012 trick 8
# 2013 protagonist 9
# 2014 ict 15
# 2015 ories 7
# 2016 excep 11
# 2017 rarely 26
# 2018 oo 47
# 2019 manipul 4
# 2020 ny 23
# 2021 conven 11
# 2022 ming 37
# 2023 clarity 8
# 2024 alls 13
# 2025 italian 8
# 2026 challeng 4
# 2027 vy 3
# 2028 modern 36
# 2029 whenever 7
# 2030 think 51
# 2031 figu 2
# 2032 late 11
# 2033 marriage 7
# 2034 throws 7
# 2035 ange 6
# 2036 ice 53
# 2037 squ 32
# 2038 ee 12
# 2039 zed 16
# 2040 symbol 8
# 2041 changes 7
# 2042 china 7
# 2043 brilliant 23
# 2044 imagination 24
# 2045 wonder 18
# 2046 guil 11
# 2047 buoyant 7
# 2048 fl 89
# 2049 emerges 12
# 2050 key 20
# 2051 flow 7
# 2052 overall 21
# 2053 fab 11
# 2054 ric 8
# 2055 hypno 7
# 2056 sters 20
# 2057 tane 11
# 2058 evo 10
# 2059 pal 20
# 2060 connec 13
# 2061 ess 74
# 2062 ones 33
# 2063 mc 23
# 2064 documentary 77
# 2065 grant 20
# 2066 major 18
# 2067 fy 6
# 2068 resist 7
# 2069 thought 23
# 2070 again 46
# 2071 lost 26
# 2072 touch 17
# 2073 adm 7
# 2074 itt 19
# 2075 midd 1
# 2076 ling 102
# 2077 bog 11
# 2078 ovich 10
# 2079 puts 19
# 2080 history 48
# 2081 vi 53
# 2082 breezy 7
# 2083 caper 8
# 2084 soul 27
# 2085 ful 74
# 2086 isive 7
# 2087 meditation 13
# 2088 ster 65
# 2089 capable 7
# 2090 eyed 14
# 2091 inten 12
# 2092 lived 9
# 2093 ties 30
# 2094 reveals 15
# 2095 important 21
# 2096 service 9
# 2097 otherwise 22
# 2098 separ 8
# 2099 good-nat 9
# 2100 found 23
# 2101 trem 10
# 2102 pri 18
# 2103 escap 22
# 2104 fare 19
# 2105 cult 7
# 2106 cliches 23
# 2107 brut 14
# 2108 0-minute 8
# 2109 battle 15
# 2110 sequence 12
# 2111 su 80
# 2112 g- 19
# 2113 grac 12
# 2114 tribute 15
# 2115 courage 7
# 2116 underst 8
# 2117 shar 6
# 2118 nation 11
# 2119 sac 12
# 2120 rif 14
# 2121 whose 42
# 2122 boo 15
# 2123 zy 9
# 2124 board 7
# 2125 jagl 7
# 2126 ized 21
# 2127 cann 7
# 2128 festival 13
# 2129 ann 9
# 2130 ual 25
# 2131 money 15
# 2132 result 17
# 2133 looking 35
# 2134 hoping 7
# 2135 hugely 8
# 2136 tening 9
# 2137 wed 8
# 2138 rip 22
# 2139 -ro 7
# 2140 aring 15
# 2141 fest 8
# 2142 yarn 10
# 2143 sne 9
# 2144 simul 8
# 2145 heart- 7
# 2146 breaking 5
# 2147 kiss 7
# 2148 disney 21
# 2149 cartoon 12
# 2150 provid 8
# 2151 unexpected 18
# 2152 ality 30
# 2153 expectation 7
# 2154 dition 11
# 2155 occasionally 19
# 2156 experim 9
# 2157 won 11
# 2158 gifted 8
# 2159 arti 19
# 2160 return 9
# 2161 reg 17
# 2162 contem 5
# 2163 clearly 14
# 2164 eting 4
# 2165 eed 6
# 2166 stri 23
# 2167 maj 8
# 2168 estic 7
# 2169 achievement 9
# 2170 igh 20
# 2171 directors 10
# 2172 members 11
# 2173 fails 31
# 2174 him 46
# 2175 super 28
# 2176 cap 25
# 2177 tured 13
# 2178 repetitive 9
# 2179 forma 3
# 2180 clear 18
# 2181 sensa 8
# 2182 tional 26
# 2183 unfl 9
# 2184 inching 7
# 2185 verse 10
# 2186 entire 19
# 2187 establ 8
# 2188 mood 23
# 2189 ring 15
# 2190 largely 11
# 2191 eleg 8
# 2192 colorful 15
# 2193 sound 13
# 2194 else 29
# 2195 succeed 7
# 2196 dres 12
# 2197 parable 7
# 2198 irresisti 7
# 2199 priv 2
# 2200 memorable 26
# 2201 suc 17
# 2202 heartbreaking 8
# 2203 heartwarming 11
# 2204 atmosphere 11
# 2205 falls 27
# 2206 somewhat 16
# 2207 short 44
# 2208 terrible 13
# 2209 prem 5
# 2210 hopeful 7
# 2211 cautionary 7
# 2212 waste 16
# 2213 div 8
# 2214 single 17
# 2215 dignity 8
# 2216 delightfully 9
# 2217 elegant 12
# 2218 plays 49
# 2219 psych 17
# 2220 ia 34
# 2221 quite 69
# 2222 chy 18
# 2223 fr 27
# 2224 popul 10
# 2225 arity 5
# 2226 eloqu 4
# 2227 need 49
# 2228 onto 8
# 2229 ryan 12
# 2230 gosling 8
# 2231 oduc 6
# 2232 influ 8
# 2233 quis 5
# 2234 itive 10
# 2235 inv 28
# 2236 performers 11
# 2237 yes 17
# 2238 hon 9
# 2239 distingu 11
# 2240 hardly 16
# 2241 bullock 13
# 2242 innoc 3
# 2243 ust 15
# 2244 passionate 8
# 2245 suffering 9
# 2246 tar 17
# 2247 figures 7
# 2248 prom 7
# 2249 proceedings 8
# 2250 ups 11
# 2251 conv 23
# 2252 lessness 7
# 2253 controver 7
# 2254 mis 62
# 2255 hilarious 28
# 2256 ripping 3
# 2257 anger 8
# 2258 10 33
# 2259 fast 12
# 2260 aimed 7
# 2261 de- 9
# 2262 several 18
# 2263 ought 7
# 2264 tel 7
# 2265 pit 11
# 2266 hope 16
# 2267 despair 9
# 2268 mid 21
# 2269 absor 4
# 2270 demanding 7
# 2271 shyamalan 10
# 2272 ple 7
# 2273 empty 12
# 2274 head 37
# 2275 fil 14
# 2276 ls 23
# 2277 purpose 13
# 2278 add 17
# 2279 body 30
# 2280 sexy 17
# 2281 pecu 7
# 2282 liar 9
# 2283 costum 9
# 2284 based 20
# 2285 events 23
# 2286 somehow 13
# 2287 consi 5
# 2288 arg 8
# 2289 highly 18
# 2290 spirited 13
# 2291 imaginative 16
# 2292 o- 23
# 2293 stin 11
# 2294 stuck 8
# 2295 afraid 9
# 2296 known 11
# 2297 creation 7
# 2892 amazing 13
# 2893 stunts 8
# 2894 coura 3
# 2895 geous 2
# 2896 ms 20
# 2897 ramsay 7
# 2898 insights 7
# 2899 sych 1
# 2900 ological 11
# 2901 thor 13
# 2902 delivered 8
# 2903 hou 4
# 2904 holds 12
# 2905 wildly 12
# 2906 makers 10
# 2907 uncompromising 8
# 2908 serve 8
# 2909 none 23
# 2910 happ 17
# 2911 angle 11
# 2912 standing 11
# 2913 dama 3
# 2914 offer 19
# 2915 either 27
# 2916 pid 7
# 2917 ci 5
# 2918 ice- 10
# 2919 rat 6
# 2920 pra 11
# 2921 subject 50
# 2922 maintains 8
# 2923 humorous 10
# 2924 politics 12
# 2925 ility 3
# 2926 west 8
# 2927 wars 8
# 2928 creates 16
# 2929 considered 7
# 2930 bon 7
# 2931 trans 17
# 2932 formation 7
# 2933 completely 31
# 2934 atory 12
# 2935 proc 14
# 2936 results 11
# 2937 emo 2
# 2938 nific 9
# 2939 created 14
# 2940 ribly 8
# 2941 sympathetic 9
# 2942 buy 10
# 2943 slight 15
# 2944 continues 7
# 2945 situations 16
# 2946 cover 8
# 2947 suspenseful 10
# 2948 heard 7
# 2949 recommend 14
# 2950 alone 15
# 2951 nic 16
# 2952 ole 15
# 2953 party 12
# 2954 nonsense 7
# 2955 ching 30
# 2956 writing 24
# 2957 aged 19
# 2958 science 10
# 2959 philosophical 10
# 2960 quir 18
# 2961 type 8
# 2962 realistic 13
# 2963 gent 14
# 2964 ele 9
# 2965 musical 8
# 2966 extravag 7
# 2967 za 7
# 2968 cheesy 10
# 2969 thrill 7
# 2970 iran 7
# 2971 tter 14
# 2972 barbershop 10
# 2973 tun 14
# 2974 baff 9
# 2975 donna 1
# 2976 tos 12
# 2977 rober 7
# 2978 ugg 9
# 2979 ero 20
# 2980 vill 13
# 2981 erous 3
# 2982 scar 11
# 2983 reach 10
# 2984 scorsese 10
# 2985 bold 8
# 2986 gang 7
# 2987 dered 5
# 2988 central 12
# 2989 nearly 40
# 2990 mesmerizing 9
# 2991 coming 16
# 2992 realize 9
# 2993 itch 9
# 2994 tran 18
# 2995 scen 18
# 2996 deliver 18
# 2997 games 9
# 2998 smar 5
# 2999 endearing 14
# 3000 lesson 7
# 3001 gg 9
# 3002 fight 9
# 3003 desperation 9
# 3004 nia 7
# 3005 ways 27
# 3006 conventional 19
# 3007 enetr 7
# 3008 current 9
# 3009 cer 6
# 3010 cinem 1
# 3011 ades 7
# 3012 equivalent 7
# 3013 tender 7
# 3014 handled 7
# 3015 college 14
# 3016 vul 7
# 3017 creep 9
# 3018 foll 18
# 3019 stand 24
# 3020 breath 8
# 3021 tak 7
# 3022 supporting 8
# 3023 quick 13
# 3024 -w 9
# 3025 possible 19
# 3026 flaws 20
# 3027 stret 10
# 3028 choices 7
# 3029 ft 14
# 3030 loves 7
# 3031 holocaust 8
# 3032 enthusias 9
# 3033 pas 17
# 3034 cul 14
# 3035 comfort 7
# 3036 embarrass 11
# 3037 atter 6
# 3038 sted 13
# 3039 teens 7
# 3040 adds 7
# 3041 subst 7
# 3042 fas 2
# 3043 intri 1
# 3044 '70s 8
# 3045 game 20
# 3046 dou 8
# 3047 nicholas 8
# 3048 nickleby 7
# 3049 dickens 7
# 3050 lovely 17
# 3051 charms 8
# 3052 martin 11
# 3053 don 13
# 3054 -l 39
# 3055 proble 6
# 3056 offensive 17
# 3057 isra 7
# 3058 on- 12
# 3059 presented 7
# 3060 intelligence 30
# 3061 saturday 8
# 3062 revel 7
# 3063 reas 7
# 3064 including 10
# 3065 crazy 13
# 3066 child 21
# 3067 sincere 11
# 3068 tful 5
# 3069 adam 9
# 3070 sandler 14
# 3071 substit 7
# 3072 ute 25
# 3073 sink 8
# 3074 exhilarating 11
# 3075 gritty 8
# 3076 compassion 7
# 3077 draw 13
# 3078 fore 2
# 3079 stil 11
# 3080 s. 5
# 3081 ler 23
# 3082 shad 14
# 3083 word 17
# 3084 farce 10
# 3085 alternately 7
# 3086 icle 2
# 3087 observations 9
# 3088 friend 14
# 3089 ships 4
# 3090 track 1
# 3091 aff 13
# 3092 inated 8
# 3093 log 7
# 3094 fly 9
# 3095 funnier 14
# 3096 bright 10
# 3097 especially 33
# 3098 television 11
# 3099 affir 9
# 3100 simpl 9
# 3101 icity 7
# 3102 mostly 28
# 3103 martha 7
# 3104 smile 10
# 3105 und 16
# 3106 dish 12
# 3107 for- 7
# 3108 commun 10
# 3109 accessible 8
# 3110 notic 7
# 3111 seat 16
# 3112 changing 11
# 3113 lan 9
# 3114 position 11
# 3115 views 7
# 3116 follow 7
# 3117 tice 3
# 3118 fit 10
# 3119 incredi 4
# 3120 t. 2
# 3121 fty 9
# 3122 journ 8
# 3123 vibr 2
# 3124 strangely 12
# 3125 course 10
# 3126 ake 11
# 3127 ounding 13
# 3128 gradually 9
# 3129 beneath 10
# 3130 ive 13
# 3131 exciting 16
# 3132 ored 13
# 3133 contr 6
# 3134 wish 17
# 3135 given 25
# 3136 drag 25
# 3137 two- 9
# 3138 melodramatic 12
# 3139 aspects 10
# 3140 start 19
# 3141 erta 3
# 3142 spr 16
# 3143 skip 8
# 3144 sligh 5
# 3145 test 11
# 3146 diffic 1
# 3147 role 24
# 3148 greek 9
# 3149 stop 12
# 3150 thought-provoking 11
# 3151 stylish 17
# 3152 ener 5
# 3153 wallace 7
# 3154 mater 3
# 3155 crack 7
# 3156 interest 34
# 3157 meandering 10
# 3158 riveting 12
# 3159 delight 13
# 3160 capture 7
# 3161 90 17
# 3162 imag 3
# 3163 talking 9
# 3164 orly 1
# 3165 boun 8
# 3166 chinese 8
# 3167 revolution 8
# 3168 hom 11
# 3169 folks 8
# 3170 aming 8
# 3171 subtlety 8
# 3172 uneven 17
# 3173 ambitious 20
# 3174 spy 21
# 3175 â 4
# 3176 personality 9
# 3177 alan 2
# 3178 surviv 7
# 3179 raw 11
# 3180 jason 10
# 3181 throughout 18
# 3182 pro 31
# 3183 dang 4
# 3184 stone 7
# 3185 conspir 8
# 3186 flashy 9
# 3187 considerable 14
# 3188 ular 11
# 3189 equ 18
# 3190 box 7
# 3191 office 11
# 3192 telling 16
# 3193 rac 10
# 3194 conf 19
# 3195 lame 12
# 3196 dum 10
# 3197 dreary 11
# 3198 recomm 6
# 3199 horrifying 7
# 3200 elements 18
# 3201 animation 24
# 3202 enthusi 1
# 3203 secre 7
# 3204 psycholog 5
# 3205 hy 11
# 3206 sett 7
# 3207 memor 7
# 3208 hackneyed 11
# 3209 effect 15
# 3210 nor 39
# 3211 motiv 11
# 3212 oddly 13
# 3213 ect 20
# 3214 ishing 12
# 3215 actresses 9
# 3216 vel 10
# 3217 eck 7
# 3218 lin 15
# 3219 murphy 15
# 3220 graph 4
# 3221 twe 6
# 3222 izes 13
# 3223 orous 10
# 3224 title 41
# 3225 berg 7
# 3226 well-crafted 7
# 3227 canny 9
# 3228 wrong 22
# 3229 animal 9
# 3230 simil 12
# 3231 arly 12
# 3232 i- 9
# 3233 machine 7
# 3234 crow 5
# 3235 stal 12
# 3236 tv 34
# 3237 ative 28
# 3238 dist 17
# 3239 port 18
# 3240 ows 31
# 3241 vam 3
# 3242 house 17
# 3243 graphic 10
# 3244 apparently 10
# 3245 grow 7
# 3246 career 15
# 3247 pad 8
# 3248 ident 8
# 3249 too- 9
# 3250 consci 7
# 3251 running 23
# 3252 -dr 8
# 3253 cliché 17
# 3254 japanese 11
# 3255 competent 9
# 3256 parts 9
# 3257 scious 2
# 3258 ñ 3
# 3259 mike 7
# 3260 shoo 13
# 3261 chance 11
# 3262 needs 17
# 3263 stay 11
# 3264 doc 7
# 3265 multi 8
# 3266 rog 4
# 3267 hell 12
# 3268 willi 4
# 3269 james 10
# 3270 upon 15
# 3271 fai 1
# 3272 smoo 7
# 3273 sues 4
# 3274 stale 13
# 3275 standard 14
# 3276 comm 22
# 3277 intoxic 2
# 3278 tast 3
# 3279 features 11
# 3280 beh 8
# 3281 allow 9
# 3282 sian 5
# 3283 ffy 11
# 3284 prove 8
# 3285 boring 29
# 3286 quest 8
# 3287 sid 7
# 3288 han 13
# 3289 turned 13
# 3290 itten 5
# 3291 cynical 7
# 3292 until 16
# 3293 endi 7
# 3294 ived 12
# 3295 damage 8
# 3296 trash 7
# 3297 hitting 7
# 3298 finish 11
# 3299 maybe 15
# 3300 formula 27
# 3301 assured 11
# 3302 pacing 16
# 3303 abov 3
# 3304 larg 2
# 3305 stereotypes 8
# 3306 matter 38
# 3307 difficult 17
# 3308 potentially 7
# 3309 previous 16
# 3310 pur 18
# 3311 pen 8
# 3312 chant 9
# 3313 life- 7
# 3314 finale 8
# 3315 lonel 1
# 3316 ots 8
# 3317 push 10
# 3318 rhythms 8
# 3319 alo 6
# 3320 chable 1
# 3321 second 18
# 3322 increasingly 8
# 3323 emphas 11
# 3324 computer 7
# 3325 favor 9
# 3326 blade 13
# 3327 bits 9
# 3328 fighting 8
# 3329 bond 12
# 3330 relies 8
# 3331 iron 7
# 3332 contrived 24
# 3333 cau 7
# 3334 ght 14
# 3335 hip-hop 10
# 3336 scratch 8
# 3337 atic 9
# 3338 improb 7
# 3339 figh 3
# 3340 ters 16
# 3341 ements 13
# 3342 tou 10
# 3343 past 29
# 3344 unab 7
# 3345 source 10
# 3346 scoo 12
# 3347 devast 4
# 3348 aston 7
# 3349 complete 14
# 3350 taking 15
# 3351 left 27
# 3352 field 5
# 3353 sun 9
# 3354 advantage 7
# 3355 present 8
# 3356 bour 8
# 3357 identity 13
# 3358 ues 4
# 3359 appe 8
# 3360 apparent 8
# 3361 ref 14
# 3362 movie- 13
# 3363 tradi 5
# 3364 awful 19
# 3365 cros 8
# 3366 question 12
# 3367 p- 11
# 3368 cour 4
# 3369 enthusiasm 7
# 3370 ises 7
# 3371 philosoph 8
# 3372 actress 16
# 3373 ï 3
# 3374 possibly 13
# 3375 orial 3
# 3376 tow 5
# 3377 ography 6
# 3378 fac 14
# 3379 medioc 5
# 3380 cares 7
# 3381 mesmer 2
# 3382 ertain 6
# 3383 wr 9
# 3384 action- 10
# 3385 fru 15
# 3386 stration 8
# 3387 viscer 2
# 3388 ellent 3
# 3389 coo 11
# 3390 conj 7
# 3391 hip 10
# 3392 shots 15
# 3393 mediocre 15
# 3394 supposed 15
# 3395 target 14
# 3396 jud 15
# 3397 diver 7
# 3398 org 8
# 3399 low 38
# 3400 smo 8
# 3401 zzle 9
# 3402 ashed 8
# 3403 determined 8
# 3404 one- 19
# 3405 uncom 9
# 3406 surpris 3
# 3407 fro 7
# 3408 zen 12
# 3409 private 7
# 3410 levels 9
# 3411 imp 14
# 3412 sible 14
# 3413 joyous 9
# 3414 messages 7
# 3415 particularly 26
# 3416 drawn 9
# 3417 sati 9
# 3418 rical 5
# 3419 const 11
# 3420 deeper 9
# 3421 pian 5
# 3422 stit 7
# 3423 cold 25
# 3424 goofy 14
# 3425 oles 4
# 3426 scrat 5
# 3427 bow 9
# 3428 talk 8
# 3429 produc 16
# 3430 herent 11
# 3431 masterful 7
# 3432 rol 6
# 3433 dream 16
# 3434 working 20
# 3435 198 8
# 3436 gio 7
# 3437 insigh 3
# 3438 insky 5
# 3439 haw 10
# 3440 plan 1
# 3441 starring 9
# 3442 sni 9
# 3443 hilar 7
# 3444 decep 12
# 3445 itable 11
# 3446 content 12
# 3447 tty 7
# 3448 detailed 9
# 3449 marvel 6
# 3450 deli 4
# 3451 remem 1
# 3452 next 25
# 3453 mur 15
# 3454 derous 8
# 3455 pap 8
# 3456 inspira 11
# 3457 saving 7
# 3458 lightweight 7
# 3459 attractive 8
# 3460 tics 19
# 3461 broo 10
# 3462 tains 5
# 3463 explos 8
# 3464 create 15
# 3465 bey 2
# 3466 wild 23
# 3467 nature 21
# 3468 faith 11
# 3469 attempts 13
# 3470 en- 12
# 3471 dig 12
# 3472 gs 14
# 3473 sugar 7
# 3474 russian 7
# 3475 aking 10
# 3476 release 12
# 3477 howard 8
# 3478 13 7
# 3479 adap 4
# 3480 superior 8
# 3481 conversa 7
# 3482 charis 6
# 3483 hun 15
# 3484 aries 11
# 3485 thy 6
# 3486 yourself 13
# 3487 giving 8
# 3488 characterizations 7
# 3489 stein 10
# 3490 remo 7
# 3491 afric 7
# 3492 guns 9
# 3493 minor 12
# 3494 obviously 7
# 3495 country 20
# 3496 amused 9
# 3497 traditional 8
# 3498 overwhel 9
# 3499 envir 1
# 3500 slap 13
# 3501 asive 8
# 3502 suspense 29
# 3503 clichés 17
# 3504 dic 18
# 3505 construc 12
# 3506 ads 17
# 3507 material 63
# 3508 releas 9
# 3509 editing 11
# 3510 alizing 7
# 3511 elev 8
# 3512 glory 7
# 3513 ere 14
# 3514 presence 9
# 3515 ills 13
# 3516 heavy 15
# 3517 atmosph 4
# 3518 eric 7
# 3519 behavior 10
# 3520 rises 10
# 3521 so- 12
# 3522 ima 11
# 3523 rand 11
# 3524 vely 6
# 3525 voice 9
# 3526 profes 4
# 3527 deserve 11
# 3528 within 10
# 3529 develop 5
# 3530 univers 1
# 3531 recogn 9
# 3532 beginning 8
# 3533 cham 7
# 3534 erce 3
# 3535 commerc 4
# 3536 reign 8
# 3537 yp 8
# 3538 nasty 9
# 3539 grade 9
# 3540 del 16
# 3541 eks 9
# 3542 offbeat 8
# 3543 of- 13
# 3544 studio 10
# 3545 hmer 10
# 3546 austin 7
# 3547 tain 10
# 3548 ask 7
# 3549 acing 16
# 3550 serves 9
# 3551 tries 29
# 3552 slip 8
# 3553 fing 10
# 3554 date 18
# 3555 totally 10
# 3556 confl 4
# 3557 shak 1
# 3558 lets 22
# 3559 ession 7
# 3560 kevin 11
# 3561 soundtrack 11
# 3562 shi 13
# 3563 already 28
# 3564 determination 7
# 3565 izing 15
# 3566 arri 14
# 3567 marg 9
# 3568 udo 7
# 3569 educ 7
# 3570 george 15
# 3571 drags 7
# 3572 refl 11
# 3573 breathtaking 7
# 3574 commentary 8
# 3575 zzy 9
# 3576 candy 7
# 3577 contemporary 16
# 3578 adoles 4
# 3579 mirac 7
# 3580 compar 13
# 3581 utions 7
# 3582 audi 4
# 3583 belongs 7
# 3584 studi 7
# 3585 dependent 7
# 3586 filling 10
# 3587 percep 7
# 3588 hur 10
# 3589 reson 9
# 3590 insul 9
# 3591 simplistic 10
# 3592 accompl 6
# 3593 bittersweet 9
# 3594 scene 24
# 3595 assu 13
# 3596 appy 1
# 3597 tile 9
# 3598 opport 6
# 3599 splendid 8
# 3600 daugh 8
# 3601 gam 7
# 3602 hill 10
# 3603 hands 8
# 3604 jum 10
# 3605 half- 12
# 3606 indi 13
# 3607 beli 7
# 3608 atten 3
# 3609 pres 19
# 3610 ll 7
# 3611 70s 4
# 3612 fem 8
# 3613 orm 7
# 3614 pion 7
# 3615 authen 4
# 3616 hall 18
# 3617 filmed 10
# 3618 exactly 17
# 3619 icism 7
# 3620 gripping 12
# 3621 watchable 20
# 3622 -minute 17
# 3623 odra 2
# 3624 low-budget 7
# 3625 ints 4
# 3626 wall 6
# 3627 wants 16
# 3628 fill 8
# 3629 dreams 14
# 3630 professional 7
# 3631 ugly 19
# 3632 til 1
# 3633 trou 5
# 3634 assass 3
# 3635 edy 7
# 3636 blair 7
# 3637 witch 8
# 3638 tech 7
# 3639 territory 9
# 3640 jec 10
# 3641 th- 9
# 3642 open 8
# 3643 horr 7
# 3644 confusing 10
# 3645 worse 17
# 3646 sustain 17
# 3647 beg 12
# 3648 inn 7
# 3649 conclusion 13
# 3650 aside 11
# 3651 leads 15
# 3652 except 15
# 3653 cal 10
# 3654 movi 1
# 3655 rout 7
# 3656 conce 17
# 3657 sloppy 11
# 3658 brilli 3
# 3659 efforts 7
# 3660 bers 2
# 3661 prot 4
# 3662 doub 11
# 3663 aly 3
# 3664 ho 20
# 3665 lea 16
# 3666 frigh 10
# 3667 spectac 4
# 3668 perspec 1
# 3669 tives 8
# 3670 differ 5
# 3671 alabama 7
# 3672 predict 3
# 3673 first-rate 7
# 3674 ands 13
# 3675 ashing 10
# 3676 preten 9
# 3677 ulous 4
# 3678 gags 21
# 3679 aute 7
# 3680 pros 8
# 3681 appeal 19
# 3682 cher 8
# 3683 .t. 2
# 3684 enty 3
# 3685 poetic 10
# 3686 lady 8
# 3687 theatrical 7
# 3688 virtually 12
# 3689 desp 1
# 3690 # 4
# 3691 epis 3
# 3692 inclu 4
# 3693 gos 3
# 3694 park 8
# 3695 mir 4
# 3696 succe 3
# 3697 bottom 9
# 3698 amateurish 12
# 3699 compas 4
# 3700 yed 5
# 3701 figure 14
# 3702 agger 9
# 3703 intell 4
# 3704 homage 8
# 3705 fra 5
# 3706 profound 7
# 3707 perfor 8
# 3708 length 10
# 3709 blue 16
# 3710 crush 17
# 3711 mildly 11
# 3712 famili 3
# 3713 wait 10
# 3714 tiv 3
# 3715 intoxicating 9
# 3716 ures 10
# 3717 inted 12
# 3718 susp 11
# 3719 busin 1
# 3720 terr 10
# 3721 spar 11
# 3722 perfec 1
# 3723 iling 11
# 3724 inspi 3
# 3725 bite 9
# 3726 trifle 7
# 3727 lane 7
# 3728 horrible 11
# 3729 bizarre 10
# 3730 def 10
# 3731 gir 9
# 3732 proper 7
# 3733 real-life 9
# 3734 sit 21
# 3735 kline 7
# 3736 dering 10
# 3737 uted 7
# 3738 bros 7
# 3739 dread 9
# 3740 expected 10
# 3741 nan 7
# 3742 aim 10
# 3743 poem 8
# 3744 ham 16
# 3745 christmas 9
# 3746 bab 10
# 3747 sec 23
# 3748 perf 3
# 3749 obnoxious 9
# 3750 exec 4
# 3751 shre 11
# 3752 turning 11
# 3753 rus 7
# 3754 ets 8
# 3755 sade 8
# 3756 rhythm 7
# 3757 demonstrates 7
# 3758 bled 16
# 3759 nijinsky 7
# 3760 soci 7
# 3761 shoul 7
# 3762 unsett 1
# 3763 grows 9
# 3764 banal 8
# 3765 wife 11
# 3766 rod 7
# 3767 ez 10
# 3768 ador 8
# 3769 lacking 19
# 3770 moves 7
# 3771 apping 7
# 3772 job 23
# 3773 first-time 7
# 3774 mental 11
# 3775 wow 8
# 3776 stam 5
# 3777 indulgent 5
# 3778 inev 7
# 3779 limited 8
# 3780 chur 7
# 3781 jag 7
# 3782 distinc 13
# 3783 sym 2
# 3784 aud 13
# 3785 acity 10
# 3786 iled 12
# 3787 ludicrous 10
# 3788 promises 7
# 3789 fal 9
# 3790 rum 7
# 3791 ud 11
# 3792 subt 8
# 3793 ounds 7
# 3794 bound 7
# 3795 curiously 7
# 3796 depressing 14
# 3797 biting 7
# 3798 jackie 7
# 3799 guilty 12
# 3800 fashioned 2
# 3801 room 18
# 3802 ordinary 9
# 3803 aving 4
# 3804 savvy 7
# 3805 portrayal 8
# 3806 roger 10
# 3807 necess 7
# 3808 orig 1
# 3809 alist 8
# 3810 drugs 7
# 3811 dri 11
# 3812 unlikely 8
# 3813 sequ 8
# 3814 terrif 6
# 3815 frequ 4
# 3816 broom 2
# 3817 manhattan 7
# 3818 avoid 9
# 3819 desc 8
# 3820 dealing 7
# 3821 stic 11
# 3822 wom 1
# 3823 dangerous 7
# 3824 guy 18
# 3825 bes 9
# 3826 itting 14
# 3827 ense 8
# 3828 extre 4
# 3829 paid 10
# 3830 harvard 8
# 3831 waiting 9
# 3832 whe 5
# 3833 rific 7
# 3834 enced 9
# 3835 bland 25
# 3836 mill 7
# 3837 offering 10
# 3838 settles 7
# 3839 sively 16
# 3840 annoying 11
# 3841 unoriginal 7
# 3842 der- 3
# 3843 chel 8
# 3844 enjo 2
# 3845 spiel 1
# 3846 further 11
# 3847 stun 9
# 3848 depend 6
# 3849 bed 7
# 3850 said 12
# 3851 dge 9
# 3852 ution 2
# 3853 chil 2
# 3854 contains 7
# 3855 nity 2
# 3856 oned 3
# 3857 interested 14
# 3858 deliber 8
# 3859 display 7
# 3860 convinc 9
# 3861 strang 8
# 3862 treasure 7
# 3863 inexplic 7
# 3864 chard 7
# 3865 daw 9
# 3866 sionate 2
# 3867 sees 7
# 3868 bunch 8
# 3869 sappy 12
# 3870 ington 3
# 3871 sin 14
# 3872 unfortunately 16
# 3873 flash 9
# 3874 æ 1
# 3875 teach 3
# 3876 incre 1
# 3877 ase 7
# 3878 ario 2
# 3879 relentlessly 7
# 3880 account 7
# 3881 fel 4
# 3882 yu 7
# 3883 ude 5
# 3884 icks 15
# 3885 cou 6
# 3886 refresh 3
# 3887 superficial 13
# 3888 cris 7
# 3889 vent 7
# 3890 bag 8
# 3891 itely 2
# 3892 enching 1
# 3893 shop 4
# 3894 grou 5
# 3895 leaving 10
# 3896 retread 9
# 3897 dimensional 10
# 3898 idence 8
# 3899 sever 1
# 3900 vide 15
# 3901 z- 7
# 3902 deta 6
# 3903 thous 7
# 3904 fying 7
# 3905 tionary 1
# 3906 ama 11
# 3907 real- 2
# 3908 sup 10
# 3909 entr 7
# 3910 dogs 7
# 3911 suspec 7
# 3912 attr 8
# 3913 twi 5
# 3914 scre 21
# 3915 mess 38
# 3916 los 12
# 3917 cause 9
# 3918 card 8
# 3919 ogn 1
# 3920 monty 8
# 3921 vs. 9
# 3922 adver 8
# 3923 pants 8
# 3924 avis 1
# 3925 lun 8
# 3926 frustrating 11
# 3927 calcul 9
# 3928 post 14
# 3929 ve- 9
# 3930 loses 11
# 3931 foo 4
# 3932 sill 8
# 3933 zzling 4
# 3934 devoid 14
# 3935 partic 7
# 3936 plain 13
# 3937 parody 9
# 3938 plo 15
# 3939 itation 9
# 3940 gone 22
# 3941 alternative 7
# 3942 rendered 7
# 3943 alien 9
# 3944 visu 2
# 3945 indeed 11
# 3946 flaw 2
# 3947 amounts 8
# 3948 aa 4
# 3949 holly 3
# 3950 appropri 3
# 3951 lazy 11
# 3952 designed 10
# 3953 snow 8
# 3954 ames 5
# 3955 effec 8
# 3956 stly 5
# 3957 irrit 2
# 3958 obnox 1
# 3959 00 7
# 3960 sugge 7
# 3961 slowly 7
# 3962 seeking 9
# 3963 ende 1
# 3964 lock 5
# 3965 barre 7
# 3966 + 1
# 3967 ghetto 7
# 3968 suffers 19
# 3969 plod 4
# 3970 structure 10
# 3971 elling 5
# 3972 failure 11
# 3973 alling 6
# 3974 downright 10
# 3975 ghost 8
# 3976 predecess 6
# 3977 rar 8
# 3978 screenwriters 8
# 3979 oss 10
# 3980 logic 8
# 3981 mil 19
# 3982 coming- 2
# 3983 rit 8
# 3984 retr 7
# 3985 feat 14
# 3986 tify 7
# 3987 focused 4
# 3988 sophistic 2
# 3989 essed 10
# 3990 kis 4
# 3991 tten 2
# 3992 appear 7
# 3993 devel 5
# 3994 particular 11
# 3995 foot 3
# 3996 crude 7
# 3997 ions 9
# 3998 teenagers 7
# 3999 reve 7
# 4000 excit 1
# 4001 formulaic 14
# 4002 godard 9
# 4003 pity 8
# 4004 immedi 12
# 4005 predictably 7
# 4006 poe 1
# 4007 searching 7
# 4008 promising 11
# 4009 fate 7
# 4010 wrought 3
# 4011 chase 9
# 4012 tired 23
# 4013 per- 11
# 4014 iler 9
# 4015 innocence 8
# 4016 determin 4
# 4017 ights 7
# 4018 metaph 4
# 4019 self-indulgent 7
# 4020 dian 9
# 4021 drop 10
# 4022 perc 1
# 4023 compe 7
# 4024 psychology 8
# 4025 survi 6
# 4026 ache 8
# 4027 biggest 9
# 4028 ette 8
# 4029 neither 29
# 4030 jan 7
# 4031 een 9
# 4032 ender 14
# 4033 fla 8
# 4034 q 11
# 4035 glass 8
# 4036 emy 7
# 4037 youn 9
# 4038 oe 7
# 4039 references 8
# 4040 kung 8
# 4041 pow 10
# 4042 nich 5
# 4043 ah 13
# 4044 ly- 7
# 4045 intellectual 7
# 4046 writers 8
# 4047 staged 8
# 4048 stir 2
# 4049 numbers 12
# 4050 mom 5
# 4051 itative 4
# 4052 worked 8
# 4053 eloquent 7
# 4054 conclu 3
# 4055 pathetic 9
# 4056 ager 9
# 4057 santa 8
# 4058 ause 6
# 4059 admit 7
# 4060 absol 4
# 4061 ison 14
# 4062 andering 4
# 4063 smoochy 7
# 4064 buo 1
# 4065 acious 11
# 4066 fort 5
# 4067 easier 8
# 4068 big- 9
# 4069 entary 4
# 4070 smug 7
# 4071 ards 8
# 4072 sod 2
# 4073 lier 8
# 4074 ddled 11
# 4075 repl 5
# 4076 at- 7
# 4077 aggres 7
# 4078 wear 8
# 4079 routine 12
# 4080 iro 5
# 4081 market 8
# 4082 oth 8
# 4083 belt 7
# 4084 showtime 10
# 4085 -looking 7
# 4086 ray 7
# 4087 owed 8
# 4088 adventures 7
# 4089 attemp 2
# 4090 ities 8
# 4091 dick 3
# 4092 extrem 2
# 4093 alter 5
# 4094 alleg 7
# 4095 bud 6
# 4096 olog 2
# 4097 rede 7
# 4098 ems 4
# 4099 ya-y 2
# 4100 shallow 16
# 4101 tack 9
# 4102 stream 3
# 4103 wasted 12
# 4104 clumsy 8
# 4105 relatively 8
# 4106 iality 7
# 4107 lad 6
# 4108 juli 9
# 4109 sophom 8
# 4110 oric 9
# 4111 kins 10
# 4112 roc 12
# 4113 ually 5
# 4114 tends 8
# 4115 mist 5
# 4116 generic 17
# 4117 aspi 8
# 4118 pil 9
# 4119 undant 7
# 4120 mers 3
# 4121 kh 7
# 4122 heav 2
# 4123 weight 13
# 4124 forgive 7
# 4125 sympa 3
# 4126 ques 4
# 4127 nowhere 9
# 4128 week 12
# 4129 repe 8
# 4130 deadly 8
# 4131 gros 2
# 4132 charact 2
# 4133 jus 7
# 4134 fied 17
# 4135 enthr 1
# 4136 crud 7
# 4137 -of-the- 7
# 4138 cross 14
# 4139 attered 9
# 4140 screenwriting 8
# 4141 painfully 15
# 4142 endless 8
# 4143 adv 9
# 4144 screenwriter 9
# 4145 sig 3
# 4146 strugg 3
# 4147 agon 2
# 4148 episod 7
# 4149 unfol 1
# 4150 fatal 9
# 4151 \/2 7
# 4152 missing 12
# 4153 erable 12
# 4154 contempor 1
# 4155 rely 3
# 4156 outra 4
# 4157 sea 17
# 4158 bir 7
# 4159 olution 5
# 4160 seemingly 7
# 4161 iev 2
# 4162 recycl 10
# 4163 ags 4
# 4164 200 3
# 4165 mistake 7
# 4166 travel 7
# 4167 earn 2
# 4168 ority 10
# 4169 acks 10
# 4170 è 2
# 4171 glimp 3
# 4172 enigma 7
# 4173 fortun 4
# 4174 cloying 9
# 4175 ben 12
# 4176 shooting 7
# 4177 foc 2
# 4178 geor 2
# 4179 ox 2
# 4180 sadly 9
# 4181 splen 3
# 4182 rent 8
# 4183 complic 6
# 4184 hil 3
# 4185 stick 4
# 4186 contin 4
# 4187 thinks 8
# 4188 cyn 6
# 4189 horrif 2
# 4190 treas 1
# 4191 moun 8
# 4192 guar 3
# 4193 heavy-handed 7
# 4194 fail 4
# 4195 satis 5
# 4196 pokemon 7
# 4197 sear 2
# 4198 eddie 8
# 4199 apses 9
# 4200 hack 2
# 4201 experi 5
# 4202 gold 9
# 4203 member 9
# 4204 edo 1
# 4205 holes 10
# 4206 unpleasant 8
# 4207 rad 7
# 4208 aded 8
# 4209 tted 10
# 4210 eg 8
# 4211 artificial 8
# 4212 hal 2
# 4213 empathy 7
# 4214 cliched 8
# 4215 dialo 2
# 4216 writer\/ 1
# 4217 propri 1
# 4218 altern 4
# 4219 esy 4
# 4220 numb 10
# 4221 -movie 7
# 4222 save 10
# 4223 intellec 3
# 4224 explic 1
# 4225 holl 7
# 4226 tually 4
# 4227 gain 8
# 4228 vampire 7
# 4229 intentions 8
# 4230 telev 1
# 4231 kapur 7
# 4232 answ 6
# 4233 oura 3
# 4234 remain 7
# 4235 active 2
# 4236 anno 2
# 4237 inspir 5
# 4238 wondering 7
# 4239 theat 5
# 4240 looked 7
# 4241 anima 1
# 4242 aul 3
# 4243 viol 3
# 4244 inist 7
# 4245 sily 7
# 4246 total 7
# 4247 onscreen 7
# 4248 tily 8
# 4249 loud 17
# 4250 ounts 1
# 4251 ycl 2
# 4252 sentim 2
# 4253 minut 2
# 4254 appears 11
# 4255 nat 9
# 4256 soun 3
# 4257 ody 1
# 4258 poor 13
# 4259 ogra 5
# 4260 comfor 1
# 4261 weak 11
# 4262 madonna 8
# 4263 itty 1
# 4264 pile 9
# 4265 dd 10
# 4266 embar 1
# 4267 docum 1
# 4268 erotic 7
# 4269 responsible 7
# 4270 ength 6
# 4271 stereotyp 5
# 4272 fiel 1
# 4273 pretends 7
# 4274 wer 8
# 4275 dle 7
# 4276 provo 5
# 4277 incon 9
# 4278 chem 1
# 4279 batt 2
# 4280 tiresome 12
# 4281 identi 2
# 4282 sop 3
# 4283 adly 1
# 4284 bear 2
# 4285 vapid 7
# 4286 stupid 22
# 4287 iter 5
# 4288 viously 1
# 4289 product 11
# 4290 incoherent 8
# 4291 51 7
# 4292 self-con 5
# 4293 drow 9
# 4294 badly 11
# 4295 ount 2
# 4296 haun 3
# 4297 pointless 14
# 4298 brit 7
# 4299 tedi 5
# 4300 plots 9
# 4301 mos 1
# 4302 plodding 8
# 4303 knoc 9
# 4304 queen 11
# 4305 unfunny 17
# 4306 writer- 2
# 4307 ill- 9
# 4308 rip-off 8
# 4309 reh 7
# 4310 inept 10
# 4311 choppy 8
# 4312 stealing 7
# 4313 not- 8
# 4314 indu 2
# 4315 wannabe 8
# 4316 ich 1
# 4317 tuxedo 7
# 4318 clum 7
# 4319 plotting 8
# 4320 low- 5
# 4321 lousy 10
# 4322 poorly 13
# 4323 bother 8
# 4324 heartwar 1
# 4325 smu 4
# 4326 rip- 1
# 4327 = 1
# 4328 whel 1
# 4329 uninspired 8
# 4330 irritating 9
# 4331 schne 8
# 4332 sity 1
# 4333 bore 12
# 4334 repeti 5
# 4335 singer 1
# 4336 listless 9
# 4337 inco 4
# 4338 laughable 8
# 4339 disguise 11
# 4340 disappoint 10
# 4341 bott 4
# 4342 sional 2
# 4343 characteriz 3
# 4344 ilities 2
# 4345 seagal 11
# 4346 lig 7
# 4347 fted 1
# 4348 tire 2
# 4349 pok 2
# 4350 thu 2
# 4351 writ 2
# 4352 joke 13
# 4353 met 2
# 4354 awk 7
# 4355 trif 1
# 4356 ready 3
# 4357 unnecessary 9
# 4358 vid 3
# 4359 quisite 2
# 4360 holi 1
# 4361 ezy 1
# 4362 dir 1
# 4363 simp 3
# 4364 -year- 1
# 4365 halfway 8
# 4366 pict 2
# 4367 exerc 1
# 4368 exploitation 9
# 4369 drug 2
# 4370 icr 1
# 4371 auth 3
# 4372 actres 1
# 4373 iction 1
# 4374 soc 5
# 4375 vap 1
# 4376 porting 1
# 4377 invol 3
# 4378 ski 4
# 4379 ridic 5
# 4380 crea 2
# 4381 indul 6
# 4382 ensive 3
# 4383 mless 10
# 4384 guing 2
# 4385 dul 3
# 4386 amate 2
# 4387 vious 1
# 4388 amateur 2
# 4389 wast 5
# 4390 peri 2
# 4391 ã 1
# 4392 retre 1
# 4393 wann 1
# 4394 hem 2
# 4395 clich 3
# 4396 provoking 2
# 4397 mani 2
# 4398 seful 1
# 4399 oqu 2
# 4400 ially 3
# 4401 intel 1
# 4402 cred 3
# 4403 tially 1
# 4404 acces 1
# 4405 chang 1
# 4406 over-the- 1
# 4407 tribu 1
# 4408 nick 1
# 4409 beha 2
# 4410 udlin 2
# 4411 deriv 1
# 4412 nec 2
# 4413 thorough 1
# 4414 behavi 1
# 4415 of-the- 5
# 4416 -rate 3
# 4417 melodra 2
# 4418 aic 1
# 4419 coming-of- 1
# 4420 fran 3
# 4421 equiv 1
# 4422 glim 2
# 4423 shakes 1
# 4424 unfortun 2
# 4425 joh 2
# 4426 nox 1
# 4427 emon 1
# 4428 gotten 2
# 4429 grad 1
# 4430 toge 1
# 4431 piec 1
# 4432 pire 1
# 4433 fig 2
# 4434 preci 1
# 4435 situ 1
# 4436 wannab 1
# 4437 barber 1
# 4438 chall 1
# 4439 centur 1
# 4440 stere 1
# 4441 forgett 1
# 4442 corn 1
# 4443 feel- 1
# 4444 aster 1
# 4445 uplif 1
# 4446 occas 1

# %%
# !python DANmodels.py --model 1a
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     /Users/anaykulkarni/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# Read in 14923 vectors of size 300
# Read in 14923 vectors of size 300
# Data loaded in : 1.0160441398620605 seconds
#
# -----------------------------------------------------------------------------------------------------------
#
# Comparing performance of Neural Networks with 2 fully connected layers, and embedding, and dropout layers
#
# Using Negative log likelihood loss function with ReLu
# Epoch #5: train accuracy 0.828, test accuracy 0.800
# Epoch #10: train accuracy 0.899, test accuracy 0.814
# Epoch #15: train accuracy 0.935, test accuracy 0.814
# Epoch #20: train accuracy 0.962, test accuracy 0.798
# Epoch #25: train accuracy 0.978, test accuracy 0.814
# Epoch #30: train accuracy 0.988, test accuracy 0.800
# Epoch #35: train accuracy 0.991, test accuracy 0.811
# Epoch #40: train accuracy 0.993, test accuracy 0.804
# Epoch #45: train accuracy 0.996, test accuracy 0.791
# Epoch #50: train accuracy 0.998, test accuracy 0.798
# Epoch #55: train accuracy 0.999, test accuracy 0.788
# Epoch #60: train accuracy 0.999, test accuracy 0.784
# Epoch #65: train accuracy 0.999, test accuracy 0.778
# Epoch #70: train accuracy 1.000, test accuracy 0.779
# Epoch #75: train accuracy 0.999, test accuracy 0.776
# Epoch #80: train accuracy 1.000, test accuracy 0.772
# Epoch #85: train accuracy 0.999, test accuracy 0.771
# Epoch #90: train accuracy 1.000, test accuracy 0.772
# Epoch #95: train accuracy 1.000, test accuracy 0.773
# Epoch #100: train accuracy 1.000, test accuracy 0.778
#
# Training completed in : 335.6849594116211 seconds
# Evaluation completed in : 1.4390735626220703 seconds
#
#
# Using Negative log likelihood loss function with tanh + sigmoid
# Epoch #5: train accuracy 0.823, test accuracy 0.790
# Epoch #10: train accuracy 0.902, test accuracy 0.814
# Epoch #15: train accuracy 0.941, test accuracy 0.821
# Epoch #20: train accuracy 0.964, test accuracy 0.820
# Epoch #25: train accuracy 0.976, test accuracy 0.812
# Epoch #30: train accuracy 0.982, test accuracy 0.808
# Epoch #35: train accuracy 0.985, test accuracy 0.799
# Epoch #40: train accuracy 0.988, test accuracy 0.800
# Epoch #45: train accuracy 0.989, test accuracy 0.799
# Epoch #50: train accuracy 0.989, test accuracy 0.798
# Epoch #55: train accuracy 0.990, test accuracy 0.796
# Epoch #60: train accuracy 0.990, test accuracy 0.798
# Epoch #65: train accuracy 0.991, test accuracy 0.794
# Epoch #70: train accuracy 0.991, test accuracy 0.787
# Epoch #75: train accuracy 0.991, test accuracy 0.796
# Epoch #80: train accuracy 0.991, test accuracy 0.788
# Epoch #85: train accuracy 0.991, test accuracy 0.786
# Epoch #90: train accuracy 0.991, test accuracy 0.784
# Epoch #95: train accuracy 0.991, test accuracy 0.786
# Epoch #100: train accuracy 0.991, test accuracy 0.786
#
# Training completed in : 344.1800944805145 seconds
# Evaluation completed in : 1.5511465072631836 seconds
#
#
# Plot saved as Figure1-train.png
#
# Plot saved as Figure1-test.png
#
# -----------------------------------------------------------------------------------------------------------
#
# Comparing performance of Neural Networks with 2 fully connected layers, and embedding, and dropout layers
#
# Using ReLu Activation functions and NLL
# Epoch #5: train accuracy 0.633, test accuracy 0.818
# Epoch #10: train accuracy 0.899, test accuracy 0.812
# Epoch #15: train accuracy 0.937, test accuracy 0.810
# Epoch #20: train accuracy 0.964, test accuracy 0.807
# Epoch #25: train accuracy 0.978, test accuracy 0.794
# Epoch #30: train accuracy 0.987, test accuracy 0.799
# Epoch #35: train accuracy 0.991, test accuracy 0.799
# Epoch #40: train accuracy 0.995, test accuracy 0.807
# Epoch #45: train accuracy 0.997, test accuracy 0.798
# Epoch #50: train accuracy 0.998, test accuracy 0.798
# Epoch #55: train accuracy 0.999, test accuracy 0.796
# Epoch #60: train accuracy 0.999, test accuracy 0.786
# Epoch #65: train accuracy 1.000, test accuracy 0.788
# Epoch #70: train accuracy 1.000, test accuracy 0.780
# Epoch #75: train accuracy 1.000, test accuracy 0.778
# Epoch #80: train accuracy 1.000, test accuracy 0.782
# Epoch #85: train accuracy 1.000, test accuracy 0.779
# Epoch #90: train accuracy 1.000, test accuracy 0.784
# Epoch #95: train accuracy 1.000, test accuracy 0.783
# Epoch #100: train accuracy 1.000, test accuracy 0.767
#
# Training completed in : 338.6879937648773 seconds
# Evaluation completed in : 1.543665885925293 seconds
#
#
#
# Using ReLu Activation functions and Cross Entropy
# Epoch #5: train accuracy 0.829, test accuracy 0.787
# Epoch #10: train accuracy 0.897, test accuracy 0.808
# Epoch #15: train accuracy 0.936, test accuracy 0.814
# Epoch #20: train accuracy 0.964, test accuracy 0.810
# Epoch #25: train accuracy 0.976, test accuracy 0.814
# Epoch #30: train accuracy 0.986, test accuracy 0.814
# Epoch #35: train accuracy 0.991, test accuracy 0.806
# Epoch #40: train accuracy 0.995, test accuracy 0.806
# Epoch #45: train accuracy 0.997, test accuracy 0.798
# Epoch #50: train accuracy 0.999, test accuracy 0.790
# Epoch #55: train accuracy 0.999, test accuracy 0.790
# Epoch #60: train accuracy 0.999, test accuracy 0.781
# Epoch #65: train accuracy 0.999, test accuracy 0.789
# Epoch #70: train accuracy 0.999, test accuracy 0.781
# Epoch #75: train accuracy 1.000, test accuracy 0.784
# Epoch #80: train accuracy 1.000, test accuracy 0.780
# Epoch #85: train accuracy 1.000, test accuracy 0.774
# Epoch #90: train accuracy 0.999, test accuracy 0.772
# Epoch #95: train accuracy 1.000, test accuracy 0.775
# Epoch #100: train accuracy 1.000, test accuracy 0.773
#
# Training completed in : 345.1169250011444 seconds
# Evaluation completed in : 1.6707119941711426 seconds
#
#
# Plot saved as Figure2-train.png
#
# Plot saved as Figure2-test.png
#
# -----------------------------------------------------------------------------------------------------------
#
# Comparing performance of Neural Networks with 2 vs 3 fully connected layers
#
# Using 2 Layer NN with ReLu and 1 dropout layer
# Epoch #5: train accuracy 0.831, test accuracy 0.800
# Epoch #10: train accuracy 0.896, test accuracy 0.814
# Epoch #15: train accuracy 0.935, test accuracy 0.811
# Epoch #20: train accuracy 0.963, test accuracy 0.806
# Epoch #25: train accuracy 0.978, test accuracy 0.807
# Epoch #30: train accuracy 0.985, test accuracy 0.799
# Epoch #35: train accuracy 0.991, test accuracy 0.805
# Epoch #40: train accuracy 0.994, test accuracy 0.807
# Epoch #45: train accuracy 0.996, test accuracy 0.791
# Epoch #50: train accuracy 0.998, test accuracy 0.797
# Epoch #55: train accuracy 0.999, test accuracy 0.790
# Epoch #60: train accuracy 0.999, test accuracy 0.779
# Epoch #65: train accuracy 0.999, test accuracy 0.784
# Epoch #70: train accuracy 1.000, test accuracy 0.783
# Epoch #75: train accuracy 1.000, test accuracy 0.778
# Epoch #80: train accuracy 1.000, test accuracy 0.776
# Epoch #85: train accuracy 1.000, test accuracy 0.774
# Epoch #90: train accuracy 1.000, test accuracy 0.773
# Epoch #95: train accuracy 1.000, test accuracy 0.774
# Epoch #100: train accuracy 1.000, test accuracy 0.772
#
# Training completed in : 350.68936419487 seconds
# Evaluation completed in : 1.7680697441101074 seconds
#
#
# Using 3 layer NN with tanh, sigmoid and 2 dropout layers
# Epoch #5: train accuracy 0.858, test accuracy 0.805
# Epoch #10: train accuracy 0.927, test accuracy 0.810
# Epoch #15: train accuracy 0.954, test accuracy 0.807
# Epoch #20: train accuracy 0.966, test accuracy 0.808
# Epoch #25: train accuracy 0.972, test accuracy 0.804
# Epoch #30: train accuracy 0.974, test accuracy 0.806
# Epoch #35: train accuracy 0.975, test accuracy 0.803
# Epoch #40: train accuracy 0.976, test accuracy 0.797
# Epoch #45: train accuracy 0.977, test accuracy 0.806
# Epoch #50: train accuracy 0.977, test accuracy 0.803
# Epoch #55: train accuracy 0.978, test accuracy 0.796
# Epoch #60: train accuracy 0.979, test accuracy 0.806
# Epoch #65: train accuracy 0.979, test accuracy 0.799
# Epoch #70: train accuracy 0.980, test accuracy 0.799
# Epoch #75: train accuracy 0.979, test accuracy 0.795
# Epoch #80: train accuracy 0.981, test accuracy 0.795
# Epoch #85: train accuracy 0.980, test accuracy 0.789
# Epoch #90: train accuracy 0.981, test accuracy 0.798
# Epoch #95: train accuracy 0.982, test accuracy 0.795
# Epoch #100: train accuracy 0.982, test accuracy 0.794
#
# Training completed in : 343.95118498802185 seconds
# Evaluation completed in : 1.8333253860473633 seconds
#
#
# Plot saved as Figure3-train.png
#
# Plot saved as Figure3-test.png
#
# -----------------------------------------------------------------------------------------------------------
#
# Since the best performance is observed for 3 Layer NN. We attempt further fine-tuning on it to see if we can get better performance
#
# Comparing performance of 3 layer Neural Networks
#
# Using 16 batch size, 100 units per hidden layer and AdamW optimizer with NLL
# Epoch #5: train accuracy 0.860, test accuracy 0.803
# Epoch #10: train accuracy 0.927, test accuracy 0.810
# Epoch #15: train accuracy 0.957, test accuracy 0.812
# Epoch #20: train accuracy 0.967, test accuracy 0.800
# Epoch #25: train accuracy 0.972, test accuracy 0.795
# Epoch #30: train accuracy 0.975, test accuracy 0.803
# Epoch #35: train accuracy 0.976, test accuracy 0.796
# Epoch #40: train accuracy 0.977, test accuracy 0.802
# Epoch #45: train accuracy 0.978, test accuracy 0.799
# Epoch #50: train accuracy 0.978, test accuracy 0.803
# Epoch #55: train accuracy 0.978, test accuracy 0.792
# Epoch #60: train accuracy 0.978, test accuracy 0.806
# Epoch #65: train accuracy 0.978, test accuracy 0.798
# Epoch #70: train accuracy 0.978, test accuracy 0.803
# Epoch #75: train accuracy 0.979, test accuracy 0.794
# Epoch #80: train accuracy 0.980, test accuracy 0.790
# Epoch #85: train accuracy 0.980, test accuracy 0.791
# Epoch #90: train accuracy 0.980, test accuracy 0.797
# Epoch #95: train accuracy 0.980, test accuracy 0.792
# Epoch #100: train accuracy 0.980, test accuracy 0.787
#
# Training completed in : 629.3588502407074 seconds
# Evaluation completed in : 1.5446786880493164 seconds
#
#
# Using 32 batch size, 128 units per hidden layer and SGD with momentum optimizer with NLL
# Epoch #5: train accuracy 0.663, test accuracy 0.649
# Epoch #10: train accuracy 0.751, test accuracy 0.759
# Epoch #15: train accuracy 0.751, test accuracy 0.798
# Epoch #20: train accuracy 0.755, test accuracy 0.790
# Epoch #25: train accuracy 0.766, test accuracy 0.787
# Epoch #30: train accuracy 0.794, test accuracy 0.811
# Epoch #35: train accuracy 0.764, test accuracy 0.789
# Epoch #40: train accuracy 0.770, test accuracy 0.749
# Epoch #45: train accuracy 0.805, test accuracy 0.807
# Epoch #50: train accuracy 0.781, test accuracy 0.688
# Epoch #55: train accuracy 0.793, test accuracy 0.766
# Epoch #60: train accuracy 0.822, test accuracy 0.780
# Epoch #65: train accuracy 0.798, test accuracy 0.802
# Epoch #70: train accuracy 0.808, test accuracy 0.808
# Epoch #75: train accuracy 0.825, test accuracy 0.803
# Epoch #80: train accuracy 0.768, test accuracy 0.628
# Epoch #85: train accuracy 0.799, test accuracy 0.718
# Epoch #90: train accuracy 0.835, test accuracy 0.749
# Epoch #95: train accuracy 0.853, test accuracy 0.757
# Epoch #100: train accuracy 0.836, test accuracy 0.742
#
# Training completed in : 234.98928952217102 seconds
# Evaluation completed in : 1.4892749786376953 seconds
#
#
# Plot saved as Figure4-train.png
#
# Plot saved as Figure4-test.png

# %%
# !python DANmodels.py --model 1b
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     /Users/anaykulkarni/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
#
# -----------------------------------------------------------------------------------------------------------
#
# Comparing performance of the 3 Layer NN with fine-tuning pretrained GloVe embeddings vs training Random Embeddings from scratch
# Read in 14923 vectors of size 300
# Read in 14923 vectors of size 300
# Data loaded in : 1.0373790264129639 seconds
#
# Training and Evaluating a 3 Layer Neural Network on Pre-trained GloVe Embeddings
# Epoch #5: train accuracy 0.862, test accuracy 0.813
# Epoch #10: train accuracy 0.927, test accuracy 0.817
# Epoch #15: train accuracy 0.957, test accuracy 0.811
# Epoch #20: train accuracy 0.967, test accuracy 0.808
# Epoch #25: train accuracy 0.970, test accuracy 0.811
# Epoch #30: train accuracy 0.973, test accuracy 0.799
# Epoch #35: train accuracy 0.974, test accuracy 0.799
# Epoch #40: train accuracy 0.976, test accuracy 0.807
# Epoch #45: train accuracy 0.977, test accuracy 0.794
# Epoch #50: train accuracy 0.977, test accuracy 0.805
# Epoch #55: train accuracy 0.978, test accuracy 0.794
# Epoch #60: train accuracy 0.977, test accuracy 0.789
# Epoch #65: train accuracy 0.979, test accuracy 0.796
# Epoch #70: train accuracy 0.979, test accuracy 0.802
# Epoch #75: train accuracy 0.979, test accuracy 0.805
# Epoch #80: train accuracy 0.980, test accuracy 0.804
# Epoch #85: train accuracy 0.979, test accuracy 0.794
# Epoch #90: train accuracy 0.979, test accuracy 0.795
# Epoch #95: train accuracy 0.980, test accuracy 0.799
# Epoch #100: train accuracy 0.979, test accuracy 0.800
#
# Training completed in : 1159.2621190547943 seconds
# Evaluation completed in : 1.5775485038757324 seconds
#
# Read in 14923 vectors of size 300
# Read in 14923 vectors of size 300
# Data loaded in : 1.1137127876281738 seconds
#
# Training (from scratch) and Evaluating a 3 Layer Neural Network on random weight embeddings
# Epoch #5: train accuracy 0.605, test accuracy 0.616
# Epoch #10: train accuracy 0.739, test accuracy 0.712
# Epoch #15: train accuracy 0.821, test accuracy 0.739
# Epoch #20: train accuracy 0.860, test accuracy 0.750
# Epoch #25: train accuracy 0.886, test accuracy 0.759
# Epoch #30: train accuracy 0.909, test accuracy 0.761
# Epoch #35: train accuracy 0.923, test accuracy 0.760
# Epoch #40: train accuracy 0.932, test accuracy 0.768
# Epoch #45: train accuracy 0.932, test accuracy 0.758
# Epoch #50: train accuracy 0.938, test accuracy 0.764
# Epoch #55: train accuracy 0.949, test accuracy 0.778
# Epoch #60: train accuracy 0.946, test accuracy 0.771
# Epoch #65: train accuracy 0.953, test accuracy 0.772
# Epoch #70: train accuracy 0.953, test accuracy 0.780
# Epoch #75: train accuracy 0.956, test accuracy 0.780
# Epoch #80: train accuracy 0.959, test accuracy 0.775
# Epoch #85: train accuracy 0.960, test accuracy 0.772
# Epoch #90: train accuracy 0.961, test accuracy 0.772
# Epoch #95: train accuracy 0.966, test accuracy 0.775
# Epoch #100: train accuracy 0.964, test accuracy 0.776
#
# Training completed in : 1629.7889177799225 seconds
# Evaluation completed in : 1.8767290115356445 seconds
#
#
# Plot saved as Figure5-train.png
#
# Plot saved as Figure5-test.png

# %%
# !python DANmodels.py --model 2a
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     /Users/anaykulkarni/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
#
# -----------------------------------------------------------------------------------------------------------
# Deep Averaging Network (DAN) with subword tokenization using Byte Pair Encoding:
# ----Loading Training Data----
# Before running BPE algorithm-------
# 	Word-level vocab size:  14830
# 	Subword-level vocab size:  64
# After running BPE algorithm--------
# 	Word-level vocab size:  14830
# 	Subword-level vocab size:  471
#
# Compression Ratio:  31.48619957537155
# ----Loading Test Data--------
# Before running BPE algorithm-------
# 	Word-level vocab size:  4339
# 	Subword-level vocab size:  53
# After running BPE algorithm--------
# 	Word-level vocab size:  4339
# 	Subword-level vocab size:  464
#
# Compression Ratio:  9.351293103448276
#
# Data loaded in : 12.588464736938477 seconds
#
# Training (from scratch) and Evaluating a 3 Layer Neural Network using BPE Subword-Level tokenization on random weight embeddings
# Epoch #5: train accuracy 0.542, test accuracy 0.509
# Epoch #10: train accuracy 0.651, test accuracy 0.492
# Epoch #15: train accuracy 0.677, test accuracy 0.503
# Epoch #20: train accuracy 0.704, test accuracy 0.475
# Epoch #25: train accuracy 0.714, test accuracy 0.486
# Epoch #30: train accuracy 0.722, test accuracy 0.487
# Epoch #35: train accuracy 0.728, test accuracy 0.490
# Epoch #40: train accuracy 0.726, test accuracy 0.485
# Epoch #45: train accuracy 0.742, test accuracy 0.495
# Epoch #50: train accuracy 0.749, test accuracy 0.505
# Epoch #55: train accuracy 0.749, test accuracy 0.509
# Epoch #60: train accuracy 0.754, test accuracy 0.510
# Epoch #65: train accuracy 0.755, test accuracy 0.516
# Epoch #70: train accuracy 0.759, test accuracy 0.510
# Epoch #75: train accuracy 0.765, test accuracy 0.506
# Epoch #80: train accuracy 0.761, test accuracy 0.517
# Epoch #85: train accuracy 0.764, test accuracy 0.509
# Epoch #90: train accuracy 0.761, test accuracy 0.506
# Epoch #95: train accuracy 0.768, test accuracy 0.508
# Epoch #100: train accuracy 0.769, test accuracy 0.513
#
# Training completed in : 46.128894567489624 seconds
# Evaluation completed in : 1.7257938385009766 seconds
#
# ----Loading Training Data----
# Read in 14923 vectors of size 300
# ----Loading Test Data--------
# Read in 14923 vectors of size 300
# Data loaded in : 1.1770129203796387 seconds
#
# Training (from scratch) and Evaluating a 3 Layer Neural Network using Word-Level tokenization on random weight embeddings
# Epoch #5: train accuracy 0.592, test accuracy 0.651
# Epoch #10: train accuracy 0.718, test accuracy 0.711
# Epoch #15: train accuracy 0.802, test accuracy 0.719
# Epoch #20: train accuracy 0.852, test accuracy 0.736
# Epoch #25: train accuracy 0.876, test accuracy 0.751
# Epoch #30: train accuracy 0.902, test accuracy 0.764
# Epoch #35: train accuracy 0.917, test accuracy 0.765
# Epoch #40: train accuracy 0.927, test accuracy 0.752
# Epoch #45: train accuracy 0.932, test accuracy 0.737
# Epoch #50: train accuracy 0.934, test accuracy 0.752
# Epoch #55: train accuracy 0.944, test accuracy 0.756
# Epoch #60: train accuracy 0.949, test accuracy 0.764
# Epoch #65: train accuracy 0.953, test accuracy 0.768
# Epoch #70: train accuracy 0.951, test accuracy 0.763
# Epoch #75: train accuracy 0.953, test accuracy 0.774
# Epoch #80: train accuracy 0.957, test accuracy 0.765
# Epoch #85: train accuracy 0.957, test accuracy 0.769
# Epoch #90: train accuracy 0.952, test accuracy 0.779
# Epoch #95: train accuracy 0.956, test accuracy 0.769
# Epoch #100: train accuracy 0.961, test accuracy 0.764
#
# Training completed in : 462.18099570274353 seconds
# Evaluation completed in : 1.5003352165222168 seconds
#
#
# Plot saved as Figure6-train.png
#
# Plot saved as Figure6-test.png
#
#
# Evaluating effect of vocabulary length on Accuracy:
# ----Loading Training Data----
# Before running BPE algorithm-------
# 	Word-level vocab size:  14830
# 	Subword-level vocab size:  64
# After running BPE algorithm--------
# 	Word-level vocab size:  14830
# 	Subword-level vocab size:  136
#
# Compression Ratio:  109.04411764705883
# ----Loading Test Data--------
# Before running BPE algorithm-------
# 	Word-level vocab size:  4339
# 	Subword-level vocab size:  53
# After running BPE algorithm--------
# 	Word-level vocab size:  4339
# 	Subword-level vocab size:  126
#
# Compression Ratio:  34.43650793650794
#
# Training (from scratch) and Evaluating a 3 Layer Neural Network using BPE (training) vocabulary size:  136
# Epoch #5: train accuracy 0.534, test accuracy 0.506
# Epoch #10: train accuracy 0.595, test accuracy 0.485
# Epoch #15: train accuracy 0.614, test accuracy 0.479
# Epoch #20: train accuracy 0.622, test accuracy 0.475
# Epoch #25: train accuracy 0.622, test accuracy 0.489
# Epoch #30: train accuracy 0.623, test accuracy 0.497
# Epoch #35: train accuracy 0.628, test accuracy 0.500
# Epoch #40: train accuracy 0.627, test accuracy 0.493
# Epoch #45: train accuracy 0.628, test accuracy 0.505
# Epoch #50: train accuracy 0.632, test accuracy 0.518
# Epoch #55: train accuracy 0.632, test accuracy 0.493
# Epoch #60: train accuracy 0.632, test accuracy 0.493
# Epoch #65: train accuracy 0.639, test accuracy 0.500
# Epoch #70: train accuracy 0.636, test accuracy 0.499
# Epoch #75: train accuracy 0.638, test accuracy 0.494
# Epoch #80: train accuracy 0.644, test accuracy 0.493
# Epoch #85: train accuracy 0.644, test accuracy 0.500
# Epoch #90: train accuracy 0.644, test accuracy 0.498
# Epoch #95: train accuracy 0.641, test accuracy 0.497
# Epoch #100: train accuracy 0.638, test accuracy 0.495
#
# Training completed in : 195.40226340293884 seconds
# Evaluation completed in : 2.3911447525024414 seconds
#
# Peak Train Accuracy achieved:  0.6460982658959538
# Peak Test Accuracy achieved:  0.518348623853211
# ----Loading Training Data----
# Before running BPE algorithm-------
# 	Word-level vocab size:  14830
# 	Subword-level vocab size:  64
# After running BPE algorithm--------
# 	Word-level vocab size:  14830
# 	Subword-level vocab size:  213
#
# Compression Ratio:  69.6244131455399
# ----Loading Test Data--------
# Before running BPE algorithm-------
# 	Word-level vocab size:  4339
# 	Subword-level vocab size:  53
# After running BPE algorithm--------
# 	Word-level vocab size:  4339
# 	Subword-level vocab size:  205
#
# Compression Ratio:  21.165853658536584
#
# Training (from scratch) and Evaluating a 3 Layer Neural Network using BPE (training) vocabulary size:  213
# Epoch #5: train accuracy 0.544, test accuracy 0.538
# Epoch #10: train accuracy 0.619, test accuracy 0.534
# Epoch #15: train accuracy 0.640, test accuracy 0.516
# Epoch #20: train accuracy 0.650, test accuracy 0.518
# Epoch #25: train accuracy 0.656, test accuracy 0.519
# Epoch #30: train accuracy 0.664, test accuracy 0.516
# Epoch #35: train accuracy 0.672, test accuracy 0.521
# Epoch #40: train accuracy 0.674, test accuracy 0.521
# Epoch #45: train accuracy 0.674, test accuracy 0.522
# Epoch #50: train accuracy 0.679, test accuracy 0.524
# Epoch #55: train accuracy 0.681, test accuracy 0.521
# Epoch #60: train accuracy 0.685, test accuracy 0.522
# Epoch #65: train accuracy 0.685, test accuracy 0.552
# Epoch #70: train accuracy 0.686, test accuracy 0.534
# Epoch #75: train accuracy 0.693, test accuracy 0.541
# Epoch #80: train accuracy 0.690, test accuracy 0.538
# Epoch #85: train accuracy 0.692, test accuracy 0.536
# Epoch #90: train accuracy 0.689, test accuracy 0.526
# Epoch #95: train accuracy 0.696, test accuracy 0.538
# Epoch #100: train accuracy 0.698, test accuracy 0.538
#
# Training completed in : 318.678946018219 seconds
# Evaluation completed in : 2.8712680339813232 seconds
#
# Peak Train Accuracy achieved:  0.6989884393063583
# Peak Test Accuracy achieved:  0.551605504587156
# ----Loading Training Data----
# Before running BPE algorithm-------
# 	Word-level vocab size:  14830
# 	Subword-level vocab size:  64
# After running BPE algorithm--------
# 	Word-level vocab size:  14830
# 	Subword-level vocab size:  296
#
# Compression Ratio:  50.101351351351354
# ----Loading Test Data--------
# Before running BPE algorithm-------
# 	Word-level vocab size:  4339
# 	Subword-level vocab size:  53
# After running BPE algorithm--------
# 	Word-level vocab size:  4339
# 	Subword-level vocab size:  293
#
# Compression Ratio:  14.80887372013652
#
# Training (from scratch) and Evaluating a 3 Layer Neural Network using BPE (training) vocabulary size:  296
# Epoch #5: train accuracy 0.541, test accuracy 0.506
# Epoch #10: train accuracy 0.631, test accuracy 0.483
# Epoch #15: train accuracy 0.662, test accuracy 0.495
# Epoch #20: train accuracy 0.678, test accuracy 0.497
# Epoch #25: train accuracy 0.687, test accuracy 0.493
# Epoch #30: train accuracy 0.695, test accuracy 0.481
# Epoch #35: train accuracy 0.699, test accuracy 0.485
# Epoch #40: train accuracy 0.700, test accuracy 0.501
# Epoch #45: train accuracy 0.707, test accuracy 0.484
# Epoch #50: train accuracy 0.707, test accuracy 0.486
# Epoch #55: train accuracy 0.713, test accuracy 0.494
# Epoch #60: train accuracy 0.716, test accuracy 0.490
# Epoch #65: train accuracy 0.722, test accuracy 0.491
# Epoch #70: train accuracy 0.719, test accuracy 0.487
# Epoch #75: train accuracy 0.720, test accuracy 0.486
# Epoch #80: train accuracy 0.721, test accuracy 0.493
# Epoch #85: train accuracy 0.725, test accuracy 0.490
# Epoch #90: train accuracy 0.727, test accuracy 0.490
# Epoch #95: train accuracy 0.728, test accuracy 0.490
# Epoch #100: train accuracy 0.735, test accuracy 0.489
#
# Training completed in : 525.4605555534363 seconds
# Evaluation completed in : 1.9260313510894775 seconds
#
# Peak Train Accuracy achieved:  0.7346820809248555
# Peak Test Accuracy achieved:  0.5401376146788991
# ----Loading Training Data----
# Before running BPE algorithm-------
# 	Word-level vocab size:  14830
# 	Subword-level vocab size:  64
# After running BPE algorithm--------
# 	Word-level vocab size:  14830
# 	Subword-level vocab size:  385
#
# Compression Ratio:  38.51948051948052
# ----Loading Test Data--------
# Before running BPE algorithm-------
# 	Word-level vocab size:  4339
# 	Subword-level vocab size:  53
# After running BPE algorithm--------
# 	Word-level vocab size:  4339
# 	Subword-level vocab size:  375
#
# Compression Ratio:  11.570666666666666
#
# Training (from scratch) and Evaluating a 3 Layer Neural Network using BPE (training) vocabulary size:  385
# Epoch #5: train accuracy 0.538, test accuracy 0.510
# Epoch #10: train accuracy 0.637, test accuracy 0.494
# Epoch #15: train accuracy 0.668, test accuracy 0.492
# Epoch #20: train accuracy 0.693, test accuracy 0.494
# Epoch #25: train accuracy 0.710, test accuracy 0.490
# Epoch #30: train accuracy 0.709, test accuracy 0.499
# Epoch #35: train accuracy 0.720, test accuracy 0.515
# Epoch #40: train accuracy 0.722, test accuracy 0.515
# Epoch #45: train accuracy 0.730, test accuracy 0.514
# Epoch #50: train accuracy 0.726, test accuracy 0.506
# Epoch #55: train accuracy 0.738, test accuracy 0.515
# Epoch #60: train accuracy 0.736, test accuracy 0.514
# Epoch #65: train accuracy 0.741, test accuracy 0.513
# Epoch #70: train accuracy 0.735, test accuracy 0.519
# Epoch #75: train accuracy 0.745, test accuracy 0.519
# Epoch #80: train accuracy 0.748, test accuracy 0.507
# Epoch #85: train accuracy 0.745, test accuracy 0.509
# Epoch #90: train accuracy 0.750, test accuracy 0.513
# Epoch #95: train accuracy 0.750, test accuracy 0.514
# Epoch #100: train accuracy 0.751, test accuracy 0.514
#
# Training completed in : 52.4056499004364 seconds
# Evaluation completed in : 2.0218563079833984 seconds
#
# Peak Train Accuracy achieved:  0.7536127167630058
# Peak Test Accuracy achieved:  0.5252293577981652
# ----Loading Training Data----
# Before running BPE algorithm-------
# 	Word-level vocab size:  14830
# 	Subword-level vocab size:  64
# After running BPE algorithm--------
# 	Word-level vocab size:  14830
# 	Subword-level vocab size:  471
#
# Compression Ratio:  31.48619957537155
# ----Loading Test Data--------
# Before running BPE algorithm-------
# 	Word-level vocab size:  4339
# 	Subword-level vocab size:  53
# After running BPE algorithm--------
# 	Word-level vocab size:  4339
# 	Subword-level vocab size:  464
#
# Compression Ratio:  9.351293103448276
#
# Training (from scratch) and Evaluating a 3 Layer Neural Network using BPE (training) vocabulary size:  471
# Epoch #5: train accuracy 0.544, test accuracy 0.484
# Epoch #10: train accuracy 0.654, test accuracy 0.470
# Epoch #15: train accuracy 0.682, test accuracy 0.478
# Epoch #20: train accuracy 0.704, test accuracy 0.481
# Epoch #25: train accuracy 0.717, test accuracy 0.479
# Epoch #30: train accuracy 0.726, test accuracy 0.499
# Epoch #35: train accuracy 0.730, test accuracy 0.502
# Epoch #40: train accuracy 0.735, test accuracy 0.508
# Epoch #45: train accuracy 0.742, test accuracy 0.498
# Epoch #50: train accuracy 0.743, test accuracy 0.495
# Epoch #55: train accuracy 0.749, test accuracy 0.509
# Epoch #60: train accuracy 0.752, test accuracy 0.501
# Epoch #65: train accuracy 0.757, test accuracy 0.500
# Epoch #70: train accuracy 0.759, test accuracy 0.514
# Epoch #75: train accuracy 0.755, test accuracy 0.524
# Epoch #80: train accuracy 0.761, test accuracy 0.505
# Epoch #85: train accuracy 0.762, test accuracy 0.522
# Epoch #90: train accuracy 0.766, test accuracy 0.507
# Epoch #95: train accuracy 0.769, test accuracy 0.519
# Epoch #100: train accuracy 0.772, test accuracy 0.500
#
# Training completed in : 60.31781721115112 seconds
# Evaluation completed in : 2.285471200942993 seconds
#
# Peak Train Accuracy achieved:  0.7718208092485549
# Peak Test Accuracy achieved:  0.5263761467889908
# ----Loading Training Data----
# Before running BPE algorithm-------
# 	Word-level vocab size:  14830
# 	Subword-level vocab size:  64
# After running BPE algorithm--------
# 	Word-level vocab size:  14830
# 	Subword-level vocab size:  561
#
# Compression Ratio:  26.4349376114082
# ----Loading Test Data--------
# Before running BPE algorithm-------
# 	Word-level vocab size:  4339
# 	Subword-level vocab size:  53
# After running BPE algorithm--------
# 	Word-level vocab size:  4339
# 	Subword-level vocab size:  553
#
# Compression Ratio:  7.84629294755877
#
# Training (from scratch) and Evaluating a 3 Layer Neural Network using BPE (training) vocabulary size:  561
# Epoch #5: train accuracy 0.535, test accuracy 0.517
# Epoch #10: train accuracy 0.665, test accuracy 0.474
# Epoch #15: train accuracy 0.706, test accuracy 0.482
# Epoch #20: train accuracy 0.722, test accuracy 0.483
# Epoch #25: train accuracy 0.735, test accuracy 0.491
# Epoch #30: train accuracy 0.742, test accuracy 0.482
# Epoch #35: train accuracy 0.751, test accuracy 0.503
# Epoch #40: train accuracy 0.754, test accuracy 0.495
# Epoch #45: train accuracy 0.755, test accuracy 0.486
# Epoch #50: train accuracy 0.764, test accuracy 0.501
# Epoch #55: train accuracy 0.771, test accuracy 0.498
# Epoch #60: train accuracy 0.768, test accuracy 0.502
# Epoch #65: train accuracy 0.774, test accuracy 0.500
# Epoch #70: train accuracy 0.779, test accuracy 0.494
# Epoch #75: train accuracy 0.777, test accuracy 0.497
# Epoch #80: train accuracy 0.777, test accuracy 0.501
# Epoch #85: train accuracy 0.783, test accuracy 0.493
# Epoch #90: train accuracy 0.786, test accuracy 0.495
# Epoch #95: train accuracy 0.783, test accuracy 0.498
# Epoch #100: train accuracy 0.780, test accuracy 0.485
#
# Training completed in : 60.40824580192566 seconds
# Evaluation completed in : 2.2043471336364746 seconds
#
# Peak Train Accuracy achieved:  0.7914739884393064
# Peak Test Accuracy achieved:  0.5172018348623854
# ----Loading Training Data----
# Before running BPE algorithm-------
# 	Word-level vocab size:  14830
# 	Subword-level vocab size:  64
# After running BPE algorithm--------
# 	Word-level vocab size:  14830
# 	Subword-level vocab size:  651
#
# Compression Ratio:  22.780337941628265
# ----Loading Test Data--------
# Before running BPE algorithm-------
# 	Word-level vocab size:  4339
# 	Subword-level vocab size:  53
# After running BPE algorithm--------
# 	Word-level vocab size:  4339
# 	Subword-level vocab size:  637
#
# Compression Ratio:  6.811616954474097
#
# Training (from scratch) and Evaluating a 3 Layer Neural Network using BPE (training) vocabulary size:  651
# Epoch #5: train accuracy 0.559, test accuracy 0.501
# Epoch #10: train accuracy 0.659, test accuracy 0.469
# Epoch #15: train accuracy 0.702, test accuracy 0.491
# Epoch #20: train accuracy 0.725, test accuracy 0.506
# Epoch #25: train accuracy 0.739, test accuracy 0.510
# Epoch #30: train accuracy 0.752, test accuracy 0.505
# Epoch #35: train accuracy 0.760, test accuracy 0.517
# Epoch #40: train accuracy 0.761, test accuracy 0.532
# Epoch #45: train accuracy 0.765, test accuracy 0.513
# Epoch #50: train accuracy 0.780, test accuracy 0.515
# Epoch #55: train accuracy 0.779, test accuracy 0.516
# Epoch #60: train accuracy 0.780, test accuracy 0.515
# Epoch #65: train accuracy 0.785, test accuracy 0.517
# Epoch #70: train accuracy 0.791, test accuracy 0.517
# Epoch #75: train accuracy 0.790, test accuracy 0.515
# Epoch #80: train accuracy 0.792, test accuracy 0.521
# Epoch #85: train accuracy 0.797, test accuracy 0.518
# Epoch #90: train accuracy 0.799, test accuracy 0.516
# Epoch #95: train accuracy 0.801, test accuracy 0.515
# Epoch #100: train accuracy 0.803, test accuracy 0.510
#
# Training completed in : 61.07654619216919 seconds
# Evaluation completed in : 2.1885058879852295 seconds
#
# Peak Train Accuracy achieved:  0.8054913294797688
# Peak Test Accuracy achieved:  0.536697247706422
# ----Loading Training Data----
# Before running BPE algorithm-------
# 	Word-level vocab size:  14830
# 	Subword-level vocab size:  64
# After running BPE algorithm--------
# 	Word-level vocab size:  14830
# 	Subword-level vocab size:  742
#
# Compression Ratio:  19.986522911051214
# ----Loading Test Data--------
# Before running BPE algorithm-------
# 	Word-level vocab size:  4339
# 	Subword-level vocab size:  53
# After running BPE algorithm--------
# 	Word-level vocab size:  4339
# 	Subword-level vocab size:  726
#
# Compression Ratio:  5.976584022038567
#
# Training (from scratch) and Evaluating a 3 Layer Neural Network using BPE (training) vocabulary size:  742
# Epoch #5: train accuracy 0.554, test accuracy 0.505
# Epoch #10: train accuracy 0.673, test accuracy 0.498
# Epoch #15: train accuracy 0.711, test accuracy 0.500
# Epoch #20: train accuracy 0.734, test accuracy 0.506
# Epoch #25: train accuracy 0.752, test accuracy 0.513
# Epoch #30: train accuracy 0.762, test accuracy 0.514
# Epoch #35: train accuracy 0.767, test accuracy 0.500
# Epoch #40: train accuracy 0.773, test accuracy 0.501
# Epoch #45: train accuracy 0.784, test accuracy 0.501
# Epoch #50: train accuracy 0.790, test accuracy 0.499
# Epoch #55: train accuracy 0.787, test accuracy 0.493
# Epoch #60: train accuracy 0.796, test accuracy 0.499
# Epoch #65: train accuracy 0.800, test accuracy 0.501
# Epoch #70: train accuracy 0.800, test accuracy 0.493
# Epoch #75: train accuracy 0.805, test accuracy 0.514
# Epoch #80: train accuracy 0.801, test accuracy 0.511
# Epoch #85: train accuracy 0.802, test accuracy 0.507
# Epoch #90: train accuracy 0.809, test accuracy 0.506
# Epoch #95: train accuracy 0.816, test accuracy 0.508
# Epoch #100: train accuracy 0.817, test accuracy 0.510
#
# Training completed in : 61.66691279411316 seconds
# Evaluation completed in : 2.188136100769043 seconds
#
# Peak Train Accuracy achieved:  0.8167630057803468
# Peak Test Accuracy achieved:  0.5217889908256881
# ----Loading Training Data----
# Before running BPE algorithm-------
# 	Word-level vocab size:  14830
# 	Subword-level vocab size:  64
# After running BPE algorithm--------
# 	Word-level vocab size:  14830
# 	Subword-level vocab size:  832
#
# Compression Ratio:  17.82451923076923
# ----Loading Test Data--------
# Before running BPE algorithm-------
# 	Word-level vocab size:  4339
# 	Subword-level vocab size:  53
# After running BPE algorithm--------
# 	Word-level vocab size:  4339
# 	Subword-level vocab size:  815
#
# Compression Ratio:  5.323926380368098
#
# Training (from scratch) and Evaluating a 3 Layer Neural Network using BPE (training) vocabulary size:  832
# Epoch #5: train accuracy 0.566, test accuracy 0.492
# Epoch #10: train accuracy 0.674, test accuracy 0.492
# Epoch #15: train accuracy 0.712, test accuracy 0.486
# Epoch #20: train accuracy 0.735, test accuracy 0.487
# Epoch #25: train accuracy 0.755, test accuracy 0.471
# Epoch #30: train accuracy 0.767, test accuracy 0.462
# Epoch #35: train accuracy 0.778, test accuracy 0.459
# Epoch #40: train accuracy 0.788, test accuracy 0.481
# Epoch #45: train accuracy 0.792, test accuracy 0.463
# Epoch #50: train accuracy 0.791, test accuracy 0.474
# Epoch #55: train accuracy 0.802, test accuracy 0.475
# Epoch #60: train accuracy 0.803, test accuracy 0.478
# Epoch #65: train accuracy 0.808, test accuracy 0.483
# Epoch #70: train accuracy 0.803, test accuracy 0.484
# Epoch #75: train accuracy 0.812, test accuracy 0.486
# Epoch #80: train accuracy 0.814, test accuracy 0.485
# Epoch #85: train accuracy 0.819, test accuracy 0.487
# Epoch #90: train accuracy 0.818, test accuracy 0.478
# Epoch #95: train accuracy 0.826, test accuracy 0.486
# Epoch #100: train accuracy 0.825, test accuracy 0.481
#
# Training completed in : 61.531230449676514 seconds
# Evaluation completed in : 2.1650197505950928 seconds
#
# Peak Train Accuracy achieved:  0.8270231213872833
# Peak Test Accuracy achieved:  0.5091743119266054
# ----Loading Training Data----
# Before running BPE algorithm-------
# 	Word-level vocab size:  14830
# 	Subword-level vocab size:  64
# After running BPE algorithm--------
# 	Word-level vocab size:  14830
# 	Subword-level vocab size:  923
#
# Compression Ratio:  16.067172264355364
# ----Loading Test Data--------
# Before running BPE algorithm-------
# 	Word-level vocab size:  4339
# 	Subword-level vocab size:  53
# After running BPE algorithm--------
# 	Word-level vocab size:  4339
# 	Subword-level vocab size:  899
#
# Compression Ratio:  4.826473859844271
#
# Training (from scratch) and Evaluating a 3 Layer Neural Network using BPE (training) vocabulary size:  923
# Epoch #5: train accuracy 0.553, test accuracy 0.513
# Epoch #10: train accuracy 0.684, test accuracy 0.546
# Epoch #15: train accuracy 0.727, test accuracy 0.555
# Epoch #20: train accuracy 0.749, test accuracy 0.570
# Epoch #25: train accuracy 0.764, test accuracy 0.558
# Epoch #30: train accuracy 0.778, test accuracy 0.545
# Epoch #35: train accuracy 0.785, test accuracy 0.556
# Epoch #40: train accuracy 0.795, test accuracy 0.561
# Epoch #45: train accuracy 0.805, test accuracy 0.554
# Epoch #50: train accuracy 0.810, test accuracy 0.542
# Epoch #55: train accuracy 0.812, test accuracy 0.549
# Epoch #60: train accuracy 0.817, test accuracy 0.550
# Epoch #65: train accuracy 0.823, test accuracy 0.554
# Epoch #70: train accuracy 0.824, test accuracy 0.554
# Epoch #75: train accuracy 0.824, test accuracy 0.542
# Epoch #80: train accuracy 0.828, test accuracy 0.547
# Epoch #85: train accuracy 0.832, test accuracy 0.550
# Epoch #90: train accuracy 0.831, test accuracy 0.548
# Epoch #95: train accuracy 0.832, test accuracy 0.553
# Epoch #100: train accuracy 0.838, test accuracy 0.550
#
# Training completed in : 72.67143774032593 seconds
# Evaluation completed in : 2.3515186309814453 seconds
#
# Peak Train Accuracy achieved:  0.8394508670520231
# Peak Test Accuracy achieved:  0.569954128440367
